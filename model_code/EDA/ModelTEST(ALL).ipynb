# %% [markdown]
# # 여러 모델을 한번에 테스트하는 용도

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.models import inception_v3, swin_t
import timm
from ultralytics import YOLO
from transformers import SwinForImageClassification, AutoImageProcessor
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import os
import random
from collections import defaultdict
import pandas as pd
import json

# %%
# ========== 설정 파라미터 ==========
# 디바이스 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# 모델 경로 설정
model_paths = {
    'YOLO': '/workspace/models/drawing_finetuned_yolov8x.pt',
    'DeiT': '/workspace/models/DeiT/Deit_finetuned_drawing.pth',
    'Swin': '/workspace/models/drawing_finetuned_swin',
    'Inception': '/workspace/models/Inception/inception_finetuned_drawing.pth'
}

# 데이터 경로
data_dir = '/workspace/testImg/val3'

# 시각화할 이미지 개수
num_visualization_images = 6
# Out:
# Using device: cuda

# %%
# ========== 클래스 정의 ==========
class_names = ['angry', 'fear', 'happy', 'sad']
class_to_idx = {name: idx for idx, name in enumerate(class_names)}

# 각 모델별 전처리 함수
def get_transforms():
    return {
        'inception': transforms.Compose([
            transforms.Resize((299, 299)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ]),
        'deit': transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ]),
        'swin': None,  # Swin은 AutoImageProcessor 사용
        'yolo': None   # YOLO는 자체 전처리 사용
    }

# %%
# 모델 로드 함수들
def load_inception_model(model_path):
    model = inception_v3(pretrained=False, num_classes=len(class_names))
    
    checkpoint = torch.load(model_path, map_location='cpu')
    
    # 체크포인트 구조 확인
    if 'model' in checkpoint:
        state_dict = checkpoint['model']
    elif 'state_dict' in checkpoint:
        state_dict = checkpoint['state_dict']
    else:
        state_dict = checkpoint
    
    # 키 매핑 (fc.1.weight -> fc.weight 등)
    new_state_dict = {}
    for key, value in state_dict.items():
        if 'fc.1.weight' in key:
            new_key = key.replace('fc.1.weight', 'fc.weight')
        elif 'fc.1.bias' in key:
            new_key = key.replace('fc.1.bias', 'fc.bias')
        else:
            new_key = key
        new_state_dict[new_key] = value
    
    model.load_state_dict(new_state_dict)
    model.eval()
    return model

def load_deit_model(model_path):
    model = timm.create_model('deit_base_patch16_224', pretrained=False, num_classes=len(class_names))
    
    checkpoint = torch.load(model_path, map_location='cpu')
    
    # 체크포인트 구조 확인
    if 'model' in checkpoint:
        state_dict = checkpoint['model']
    elif 'state_dict' in checkpoint:
        state_dict = checkpoint['state_dict']
    else:
        state_dict = checkpoint
    
    model.load_state_dict(state_dict)
    model.eval()
    return model

def load_swin_model(model_path):
    """
    Hugging Face Transformers 방식으로 Swin 모델 로드
    """
    try:
        # Hugging Face 방식으로 모델 로드
        model = SwinForImageClassification.from_pretrained(model_path)
        processor = AutoImageProcessor.from_pretrained(model_path)
        
        # 클래스 정보 로드
        class_info_path = os.path.join(model_path, 'class_info.json')
        if os.path.exists(class_info_path):
            with open(class_info_path, 'r') as f:
                class_info = json.load(f)
        else:
            # 기본 클래스 정보 사용
            class_info = {'class_names': class_names}
        
        model.eval()
        return model, processor, class_info
        
    except Exception as e:
        print(f"Error loading Swin model with Hugging Face: {e}")
        # 폴백: torchvision 방식으로 시도
        model = swin_t(pretrained=False, num_classes=len(class_names))
        
        # 폴더로 저장되어 있다면 적절히 로드
        if os.path.isdir(model_path):
            # 폴더 내에서 모델 파일 찾기
            possible_files = []
            for root, dirs, files in os.walk(model_path):
                for file in files:
                    if file.endswith('.pth') or file.endswith('.pt'):
                        possible_files.append(os.path.join(root, file))
            
            if possible_files:
                model_path = possible_files[0]  # 첫 번째 모델 파일 사용
                print(f"Loading Swin model from: {model_path}")
            else:
                raise FileNotFoundError(f"No model files found in {model_path}")
        
        checkpoint = torch.load(model_path, map_location='cpu')
        
        # 체크포인트 구조 확인 및 적절한 키 사용
        if 'model' in checkpoint:
            model.load_state_dict(checkpoint['model'])
        elif 'state_dict' in checkpoint:
            model.load_state_dict(checkpoint['state_dict'])
        else:
            model.load_state_dict(checkpoint)
        
        model.eval()
        return model, None, {'class_names': class_names}

def load_yolo_model(model_path):
    model = YOLO(model_path)
    return model

# 예측 함수들
def predict_torch_model(model, image_path, transform, device):
    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image).unsqueeze(0).to(device)
    
    with torch.no_grad():
        outputs = model(image_tensor)
        if isinstance(outputs, tuple):  # Inception의 경우
            outputs = outputs[0]
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1).item()
        confidence = probabilities[0][predicted_class].item()
    
    return predicted_class, confidence, probabilities[0].cpu().numpy()

def predict_swin_model(model, processor, class_info, image_path, device):
    """
    Hugging Face Transformers 방식으로 Swin 모델 예측
    """
    image = Image.open(image_path).convert('RGB')
    
    if processor is not None:
        # Hugging Face 방식
        inputs = processor(image, return_tensors="pt").to(device)
        
        with torch.no_grad():
            outputs = model(**inputs)
            probabilities = torch.nn.functional.softmax(outputs.logits, dim=-1)
            predicted_class = torch.argmax(probabilities, dim=-1).item()
            confidence = probabilities[0][predicted_class].item()
        
        return predicted_class, confidence, probabilities[0].cpu().numpy()
    else:
        # 폴백: torchvision 방식
        transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        
        image_tensor = transform(image).unsqueeze(0).to(device)
        
        with torch.no_grad():
            outputs = model(image_tensor)
            probabilities = torch.nn.functional.softmax(outputs, dim=1)
            predicted_class = torch.argmax(probabilities, dim=1).item()
            confidence = probabilities[0][predicted_class].item()
        
        return predicted_class, confidence, probabilities[0].cpu().numpy()

def predict_yolo_model(model, image_path):
    results = model(image_path)
    
    if len(results) > 0 and hasattr(results[0], 'probs') and results[0].probs is not None:
        # Classification 모델의 경우
        probs = results[0].probs.data.cpu().numpy()
        predicted_class = np.argmax(probs)
        confidence = probs[predicted_class]
        
        return predicted_class, confidence, probs
    elif len(results) > 0 and hasattr(results[0], 'boxes') and results[0].boxes is not None and len(results[0].boxes) > 0:
        # Detection 모델의 경우 (원래 코드)
        confidences = results[0].boxes.conf.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()
        
        max_conf_idx = np.argmax(confidences)
        predicted_class = int(classes[max_conf_idx])
        confidence = confidences[max_conf_idx]
        
        # 확률 분포 생성 (단순화된 버전)
        probabilities = np.zeros(len(class_names))
        probabilities[predicted_class] = confidence
        
        return predicted_class, confidence, probabilities
    else:
        # 예측 실패 시 기본값
        return 0, 0.0, np.zeros(len(class_names))

# 데이터셋 로드
def load_dataset(data_dir):
    dataset = []
    for class_name in class_names:
        class_dir = os.path.join(data_dir, class_name)
        if os.path.exists(class_dir):
            for img_file in os.listdir(class_dir):
                if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    img_path = os.path.join(class_dir, img_file)
                    dataset.append((img_path, class_to_idx[class_name]))
    return dataset

# 모델 평가
def evaluate_model(model, dataset, model_type, transforms_dict, device, swin_processor=None, swin_class_info=None):
    correct = 0
    total = 0
    predictions = []
    
    for img_path, true_label in dataset:
        try:
            if model_type == 'yolo':
                pred_class, confidence, probabilities = predict_yolo_model(model, img_path)
            elif model_type == 'swin':
                pred_class, confidence, probabilities = predict_swin_model(
                    model, swin_processor, swin_class_info, img_path, device
                )
            else:
                pred_class, confidence, probabilities = predict_torch_model(
                    model, img_path, transforms_dict[model_type], device
                )
            
            predictions.append({
                'image_path': img_path,
                'true_label': true_label,
                'predicted_label': pred_class,
                'confidence': confidence,
                'probabilities': probabilities
            })
            
            if pred_class == true_label:
                correct += 1
            total += 1
            
        except Exception as e:
            print(f"Error processing {img_path}: {e}")
            continue
    
    accuracy = correct / total if total > 0 else 0
    return accuracy, predictions

# 시각화 함수
def visualize_predictions(sample_predictions, model_names):
    fig, axes = plt.subplots(len(sample_predictions), len(model_names) + 1, 
                            figsize=(4 * (len(model_names) + 1), 4 * len(sample_predictions)))
    
    if len(sample_predictions) == 1:
        axes = axes.reshape(1, -1)
    
    for i, sample in enumerate(sample_predictions):
        img_path = sample['image_path']
        true_label = sample['true_label']
        
        # 원본 이미지 표시
        img = Image.open(img_path).convert('RGB')
        axes[i, 0].imshow(img)
        axes[i, 0].set_title(f'Original\nTrue: {class_names[true_label]}')
        axes[i, 0].axis('off')
        
        # 각 모델별 예측 결과 표시
        for j, model_name in enumerate(model_names):
            pred_data = sample[model_name]
            pred_class = pred_data['predicted_label']
            confidence = pred_data['confidence']
            probabilities = pred_data['probabilities']
            
            # 확률 분포 시각화
            axes[i, j+1].bar(class_names, probabilities, alpha=0.7)
            axes[i, j+1].set_title(f'{model_name}\nPred: {class_names[pred_class]}\nConf: {confidence:.3f}')
            axes[i, j+1].set_ylim(0, 1)
            axes[i, j+1].tick_params(axis='x', rotation=45)
            
            # 정답 여부에 따른 색상 구분
            if pred_class == true_label:
                axes[i, j+1].set_facecolor('lightgreen')
            else:
                axes[i, j+1].set_facecolor('lightcoral')
    
    plt.tight_layout()
    plt.savefig('/workspace/model_comparison_results.png', dpi=300, bbox_inches='tight')
    plt.show()

# 정확도 비교 시각화
def plot_accuracy_comparison(accuracies):
    plt.figure(figsize=(10, 6))
    
    models = list(accuracies.keys())
    acc_values = list(accuracies.values())
    
    bars = plt.bar(models, acc_values, alpha=0.7, color=['skyblue', 'lightgreen', 'lightcoral', 'gold'])
    plt.ylabel('Accuracy')
    plt.title('Model Accuracy Comparison')
    plt.ylim(0, 1)
    
    # 각 막대 위에 정확도 값 표시
    for bar, acc in zip(bars, acc_values):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, 
                f'{acc:.3f}', ha='center', va='bottom', fontweight='bold')
    
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('/workspace/accuracy_comparison.png', dpi=300, bbox_inches='tight')
    plt.show()

# ========== 실행 코드 ==========
# 전처리 함수 로드
transforms_dict = get_transforms()

# 데이터셋 로드
print("Loading dataset...")
dataset = load_dataset(data_dir)
print(f"Loaded {len(dataset)} images")

# 모델 로드 및 평가
models = {}
accuracies = {}
all_predictions = {}
swin_processor = None
swin_class_info = None

# YOLO 모델
print("\nEvaluating YOLO model...")
try:
    models['YOLO'] = load_yolo_model(model_paths['YOLO'])
    accuracy, predictions = evaluate_model(models['YOLO'], dataset, 'yolo', transforms_dict, device)
    accuracies['YOLO'] = accuracy
    all_predictions['YOLO'] = predictions
    print(f"YOLO Accuracy: {accuracy:.3f}")
except Exception as e:
    print(f"Error with YOLO model: {e}")
    accuracies['YOLO'] = 0.0

# DeiT 모델
print("\nEvaluating DeiT model...")
try:
    models['DeiT'] = load_deit_model(model_paths['DeiT']).to(device)
    accuracy, predictions = evaluate_model(models['DeiT'], dataset, 'deit', transforms_dict, device)
    accuracies['DeiT'] = accuracy
    all_predictions['DeiT'] = predictions
    print(f"DeiT Accuracy: {accuracy:.3f}")
except Exception as e:
    print(f"Error with DeiT model: {e}")
    accuracies['DeiT'] = 0.0

# Swin 모델
print("\nEvaluating Swin model...")
try:
    swin_model, swin_processor, swin_class_info = load_swin_model(model_paths['Swin'])
    models['Swin'] = swin_model.to(device)
    accuracy, predictions = evaluate_model(
        models['Swin'], dataset, 'swin', transforms_dict, device, 
        swin_processor=swin_processor, swin_class_info=swin_class_info
    )
    accuracies['Swin'] = accuracy
    all_predictions['Swin'] = predictions
    print(f"Swin Accuracy: {accuracy:.3f}")
except Exception as e:
    print(f"Error with Swin model: {e}")
    accuracies['Swin'] = 0.0

# Inception 모델
print("\nEvaluating Inception model...")
try:
    models['Inception'] = load_inception_model(model_paths['Inception']).to(device)
    accuracy, predictions = evaluate_model(models['Inception'], dataset, 'inception', transforms_dict, device)
    accuracies['Inception'] = accuracy
    all_predictions['Inception'] = predictions
    print(f"Inception Accuracy: {accuracy:.3f}")
except Exception as e:
    print(f"Error with Inception model: {e}")
    accuracies['Inception'] = 0.0

# 결과 출력
print("\n" + "="*50)
print("MODEL COMPARISON RESULTS")
print("="*50)

for model_name, accuracy in accuracies.items():
    print(f"{model_name:12}: {accuracy:.3f}")

# 정확도 비교 시각화
plot_accuracy_comparison(accuracies)

# 랜덤 샘플 시각화
if all_predictions:
    available_models = [name for name in all_predictions.keys() if len(all_predictions[name]) > 0]
    
    if available_models:
        # 모든 모델이 예측한 이미지들 중에서 랜덤 선택
        common_images = set(pred['image_path'] for pred in all_predictions[available_models[0]])
        for model_name in available_models[1:]:
            model_images = set(pred['image_path'] for pred in all_predictions[model_name])
            common_images = common_images.intersection(model_images)
        
        if len(common_images) >= num_visualization_images:
            sample_images = random.sample(list(common_images), num_visualization_images)
            
            # 각 샘플에 대한 모든 모델의 예측 정보 수집
            sample_predictions = []
            for img_path in sample_images:
                sample_data = {'image_path': img_path}
                
                for model_name in available_models:
                    for pred in all_predictions[model_name]:
                        if pred['image_path'] == img_path:
                            sample_data['true_label'] = pred['true_label']
                            sample_data[model_name] = pred
                            break
                
                sample_predictions.append(sample_data)
            
            # 시각화
            print(f"\nVisualizing predictions for {len(sample_predictions)} random samples...")
            visualize_predictions(sample_predictions, available_models)
        else:
            print(f"Not enough common images for visualization. Found {len(common_images)} common images.")
# Out:
# Loading dataset...
# Loaded 1586 images
#
# Evaluating YOLO model...
# image 1/1 /workspace/testImg/val3/angry/angry_313.jpeg: 224x224 angry 0.86, fear 0.09, sad 0.03, happy 0.02, 4.8ms
# Speed: 7.7ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_312.jpeg: 224x224 fear 0.97, angry 0.03, sad 0.00, happy 0.00, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_311.jpeg: 224x224 angry 0.98, fear 0.01, sad 0.00, happy 0.00, 5.3ms
# Speed: 3.8ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_310.jpeg: 224x224 angry 0.91, sad 0.07, fear 0.02, happy 0.00, 5.0ms
# Speed: 0.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_309.jpeg: 224x224 fear 0.62, angry 0.37, sad 0.01, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_308.jpeg: 224x224 angry 0.92, fear 0.08, sad 0.00, happy 0.00, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_307.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_306.jpeg: 224x224 fear 0.83, angry 0.17, sad 0.01, happy 0.00, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_305.jpeg: 224x224 angry 0.95, sad 0.04, fear 0.01, happy 0.00, 5.5ms
# Speed: 53.0ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_304.jpeg: 224x224 angry 0.92, happy 0.07, sad 0.01, fear 0.00, 5.1ms
# Speed: 4.5ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_303.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 69.8ms
# Speed: 1.5ms preprocess, 69.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_302.jpeg: 224x224 angry 0.88, fear 0.12, sad 0.00, happy 0.00, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_301.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_300.jpeg: 224x224 angry 0.51, sad 0.49, fear 0.00, happy 0.00, 4.6ms
# Speed: 55.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_299.jpeg: 224x224 angry 0.89, fear 0.10, sad 0.00, happy 0.00, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_298.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_297.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 5.2ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_296.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.1ms
# Speed: 4.8ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_295.jpg: 224x224 angry 0.98, sad 0.01, fear 0.01, happy 0.00, 5.7ms
# Speed: 5.0ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_294.jpeg: 224x224 angry 0.94, fear 0.06, sad 0.00, happy 0.00, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_293.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.5ms
# Speed: 72.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_292.jpeg: 224x224 angry 0.97, sad 0.02, fear 0.01, happy 0.00, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_291.jpeg: 224x224 angry 0.96, fear 0.04, sad 0.00, happy 0.00, 74.6ms
# Speed: 1.7ms preprocess, 74.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_290.jpeg: 224x224 angry 0.96, fear 0.04, sad 0.00, happy 0.00, 5.5ms
# Speed: 5.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_289.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 3.7ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_288.jpeg: 224x224 angry 0.97, fear 0.02, sad 0.01, happy 0.00, 5.1ms
# Speed: 64.8ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_287.jpeg: 224x224 angry 0.88, fear 0.11, sad 0.01, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_286.jpeg: 224x224 angry 0.97, fear 0.03, sad 0.00, happy 0.00, 78.6ms
# Speed: 1.2ms preprocess, 78.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_285.jpg: 224x224 angry 0.94, sad 0.03, fear 0.02, happy 0.02, 5.7ms
# Speed: 14.1ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_284.png: 224x224 angry 0.62, sad 0.27, fear 0.09, happy 0.01, 7.2ms
# Speed: 59.9ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_283.jpg: 224x224 angry 0.95, happy 0.03, sad 0.01, fear 0.00, 7.5ms
# Speed: 85.9ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_282.jpg: 224x224 angry 1.00, fear 0.00, happy 0.00, sad 0.00, 5.5ms
# Speed: 82.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_281.jpg: 224x224 angry 0.85, fear 0.15, sad 0.00, happy 0.00, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_280.jpg: 224x224 angry 0.86, sad 0.13, happy 0.01, fear 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_279.jpg: 224x224 angry 0.87, happy 0.10, fear 0.02, sad 0.01, 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_278.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.6ms
# Speed: 4.3ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_277.jpeg: 224x224 fear 0.56, angry 0.44, sad 0.01, happy 0.00, 49.7ms
# Speed: 1.3ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_276.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_275.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_274.jpeg: 224x224 angry 0.97, fear 0.03, sad 0.00, happy 0.00, 9.0ms
# Speed: 72.2ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_273.jpg: 224x224 angry 0.98, fear 0.02, sad 0.00, happy 0.00, 8.7ms
# Speed: 84.4ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_272.jpeg: 224x224 fear 0.96, angry 0.02, sad 0.02, happy 0.00, 73.9ms
# Speed: 2.1ms preprocess, 73.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_271.jpeg: 224x224 angry 0.94, sad 0.06, fear 0.00, happy 0.00, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_270.jpeg: 224x224 fear 0.54, angry 0.43, sad 0.02, happy 0.00, 5.8ms
# Speed: 2.5ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_269.jpeg: 224x224 angry 0.99, sad 0.00, fear 0.00, happy 0.00, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_268.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_267.jpeg: 224x224 angry 0.95, fear 0.05, sad 0.00, happy 0.00, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_266.jpeg: 224x224 angry 0.63, sad 0.30, fear 0.07, happy 0.00, 68.4ms
# Speed: 1.6ms preprocess, 68.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_265.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 14.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_264.jpg: 224x224 sad 0.57, angry 0.42, fear 0.01, happy 0.00, 9.8ms
# Speed: 9.8ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_263.jpeg: 224x224 angry 0.98, fear 0.02, sad 0.00, happy 0.00, 5.8ms
# Speed: 69.3ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_262.jpeg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 6.0ms
# Speed: 3.6ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_261.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.9ms
# Speed: 8.5ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_260.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 6.1ms
# Speed: 3.3ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_259.jpeg: 224x224 angry 0.89, sad 0.06, fear 0.05, happy 0.00, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_258.jpeg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 72.4ms
# Speed: 8.1ms preprocess, 72.4ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_255.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.9ms
# Speed: 11.9ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_254.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.8ms
# Speed: 69.2ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_253.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_252.jpeg: 224x224 angry 0.99, fear 0.01, happy 0.00, sad 0.00, 4.9ms
# Speed: 96.5ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_251.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.4ms
# Speed: 3.7ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_250.png: 224x224 angry 0.70, sad 0.30, happy 0.00, fear 0.00, 5.8ms
# Speed: 180.4ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_249.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 78.2ms
# Speed: 1.4ms preprocess, 78.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_248.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 4.3ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_247.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_246.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.0ms
# Speed: 59.6ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_245.jpeg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_244.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 64.7ms
# Speed: 1.7ms preprocess, 64.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_243.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 6.1ms
# Speed: 4.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_242.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 74.9ms
# Speed: 1.5ms preprocess, 74.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_241.jpg: 224x224 angry 0.99, fear 0.01, sad 0.00, happy 0.00, 5.7ms
# Speed: 4.3ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_240.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_239.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 6.1ms
# Speed: 72.0ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_238.jpg: 224x224 angry 0.98, sad 0.01, happy 0.01, fear 0.00, 5.4ms
# Speed: 77.9ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_237.jpg: 224x224 angry 0.98, happy 0.01, fear 0.01, sad 0.00, 5.7ms
# Speed: 3.7ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_236.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 74.6ms
# Speed: 1.1ms preprocess, 74.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_235.jpg: 224x224 angry 0.99, sad 0.01, fear 0.00, happy 0.00, 81.3ms
# Speed: 10.2ms preprocess, 81.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_234.jpg: 224x224 angry 0.99, sad 0.00, fear 0.00, happy 0.00, 6.0ms
# Speed: 94.6ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_233.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 79.6ms
# Speed: 7.5ms preprocess, 79.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_232.jpg: 224x224 angry 0.71, happy 0.24, fear 0.03, sad 0.02, 5.4ms
# Speed: 10.1ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_231.jpg: 224x224 angry 0.56, fear 0.34, sad 0.08, happy 0.01, 4.9ms
# Speed: 0.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_230.jpg: 224x224 angry 0.96, fear 0.04, sad 0.00, happy 0.00, 5.5ms
# Speed: 13.9ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_229.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.5ms
# Speed: 72.7ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_228.jpg: 224x224 angry 0.71, fear 0.26, happy 0.02, sad 0.00, 4.8ms
# Speed: 93.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_227.jpg: 224x224 fear 0.79, angry 0.19, sad 0.02, happy 0.01, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_226.jpg: 224x224 angry 0.47, fear 0.45, happy 0.06, sad 0.02, 5.8ms
# Speed: 64.3ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_225.jpg: 224x224 angry 1.00, happy 0.00, sad 0.00, fear 0.00, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_224.jpg: 224x224 happy 0.80, angry 0.19, fear 0.01, sad 0.00, 74.8ms
# Speed: 1.0ms preprocess, 74.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_223.jpg: 224x224 happy 0.78, angry 0.22, sad 0.00, fear 0.00, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_222.jpg: 224x224 angry 1.00, fear 0.00, happy 0.00, sad 0.00, 4.9ms
# Speed: 0.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_221.jpg: 224x224 angry 0.98, fear 0.02, sad 0.00, happy 0.00, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_220.jpg: 224x224 angry 0.99, sad 0.01, fear 0.00, happy 0.00, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_219.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_218.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.3ms
# Speed: 0.9ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_217.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_216.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_215.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.5ms
# Speed: 79.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_214.jpg: 224x224 angry 0.99, happy 0.00, sad 0.00, fear 0.00, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_213.jpg: 224x224 angry 0.90, sad 0.08, fear 0.02, happy 0.00, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_212.jpg: 224x224 angry 0.99, sad 0.01, fear 0.00, happy 0.00, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_211.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_210.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_209.jpg: 224x224 angry 0.99, sad 0.01, fear 0.00, happy 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_208.jpg: 224x224 angry 0.97, fear 0.02, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_207.jpg: 224x224 fear 0.54, angry 0.45, sad 0.01, happy 0.00, 4.7ms
# Speed: 14.3ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_206.jpg: 224x224 angry 1.00, happy 0.00, fear 0.00, sad 0.00, 4.8ms
# Speed: 72.5ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_205.jpg: 224x224 angry 0.95, fear 0.04, happy 0.01, sad 0.01, 4.1ms
# Speed: 0.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_204.jpg: 224x224 angry 0.92, sad 0.08, fear 0.00, happy 0.00, 4.0ms
# Speed: 0.8ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_203.jpg: 224x224 angry 0.99, fear 0.00, sad 0.00, happy 0.00, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_202.jpg: 224x224 angry 0.98, fear 0.01, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_201.jpg: 224x224 angry 1.00, fear 0.00, happy 0.00, sad 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_200.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 2.8ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_199.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.9ms
# Speed: 0.8ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_198.jpg: 224x224 angry 0.91, fear 0.05, sad 0.02, happy 0.02, 4.2ms
# Speed: 0.8ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_197.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_196.jpg: 224x224 sad 0.78, angry 0.17, fear 0.03, happy 0.02, 9.2ms
# Speed: 1.3ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_195.jpg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 5.5ms
# Speed: 73.9ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_194.jpg: 224x224 angry 0.93, fear 0.04, happy 0.02, sad 0.00, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_193.jpg: 224x224 sad 0.60, angry 0.40, fear 0.00, happy 0.00, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_192.jpg: 224x224 angry 0.99, fear 0.00, happy 0.00, sad 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_191.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.1ms
# Speed: 0.8ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_190.jpg: 224x224 angry 0.98, happy 0.01, sad 0.00, fear 0.00, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_189.jpg: 224x224 angry 0.89, fear 0.06, happy 0.03, sad 0.01, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_188.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 75.9ms
# Speed: 0.8ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_187.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_186.jpg: 224x224 angry 0.95, happy 0.04, fear 0.00, sad 0.00, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_185.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 76.0ms
# Speed: 0.8ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_184.jpg: 224x224 angry 0.85, sad 0.15, fear 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_183.jpg: 224x224 angry 0.81, fear 0.19, sad 0.00, happy 0.00, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_182.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_181.jpg: 224x224 angry 0.99, fear 0.01, sad 0.01, happy 0.00, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_180.jpg: 224x224 angry 0.50, fear 0.30, happy 0.15, sad 0.04, 8.0ms
# Speed: 0.9ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_179.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 68.1ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_178.jpg: 224x224 angry 0.53, fear 0.18, happy 0.16, sad 0.13, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_177.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 66.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_176.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_175.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_174.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 65.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_173.jpg: 224x224 angry 0.96, sad 0.03, fear 0.01, happy 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_172.jpg: 224x224 angry 1.00, fear 0.00, happy 0.00, sad 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_171.jpg: 224x224 angry 0.96, fear 0.03, sad 0.00, happy 0.00, 5.3ms
# Speed: 64.6ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_170.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_169.jpg: 224x224 angry 0.99, fear 0.01, sad 0.00, happy 0.00, 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_168.jpg: 224x224 angry 0.97, sad 0.03, fear 0.00, happy 0.00, 5.3ms
# Speed: 64.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_167.jpg: 224x224 angry 0.97, fear 0.03, sad 0.00, happy 0.00, 4.7ms
# Speed: 1.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_166.jpg: 224x224 angry 0.97, happy 0.02, fear 0.01, sad 0.00, 76.8ms
# Speed: 0.9ms preprocess, 76.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_165.jpg: 224x224 angry 0.70, fear 0.30, sad 0.00, happy 0.00, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_164.jpeg: 224x224 angry 0.99, fear 0.01, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_163.jpg: 224x224 angry 0.62, sad 0.24, happy 0.12, fear 0.02, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_162.jpg: 224x224 angry 0.99, happy 0.01, fear 0.01, sad 0.00, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_161.jpeg: 224x224 sad 0.83, fear 0.15, angry 0.02, happy 0.00, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_160.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 8.7ms
# Speed: 0.8ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_159.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_158.jpeg: 224x224 angry 0.97, sad 0.03, fear 0.00, happy 0.00, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_157.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_156.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_155.jpeg: 224x224 angry 0.87, fear 0.12, sad 0.00, happy 0.00, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_154.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 78.0ms
# Speed: 0.9ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_153.jpeg: 224x224 angry 0.98, fear 0.01, happy 0.01, sad 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_152.jpeg: 224x224 angry 0.99, happy 0.01, sad 0.00, fear 0.00, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_151.jpg: 224x224 fear 0.84, sad 0.16, happy 0.00, angry 0.00, 5.4ms
# Speed: 74.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_150.jpeg: 224x224 angry 0.57, sad 0.36, fear 0.06, happy 0.00, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_149.jpeg: 224x224 angry 0.86, fear 0.11, sad 0.04, happy 0.00, 5.4ms
# Speed: 3.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_148.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_147.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.3ms
# Speed: 65.1ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_146.jpeg: 224x224 angry 0.93, fear 0.04, sad 0.02, happy 0.00, 4.6ms
# Speed: 1.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_145.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.2ms
# Speed: 0.9ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_144.jpeg: 224x224 angry 1.00, happy 0.00, sad 0.00, fear 0.00, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_143.jpeg: 224x224 angry 0.93, fear 0.06, sad 0.01, happy 0.00, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_142.jpeg: 224x224 angry 0.97, fear 0.03, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_141.jpeg: 224x224 angry 0.62, fear 0.32, sad 0.06, happy 0.00, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_140.jpg: 224x224 sad 1.00, angry 0.00, fear 0.00, happy 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_139.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 7.9ms
# Speed: 0.8ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_138.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_137.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 7.9ms
# Speed: 0.9ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_136.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 1.2ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_135.jpeg: 224x224 angry 0.98, sad 0.02, fear 0.00, happy 0.00, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_134.jpeg: 224x224 angry 0.83, fear 0.13, sad 0.04, happy 0.00, 9.0ms
# Speed: 0.8ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_133.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.4ms
# Speed: 67.5ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_132.jpeg: 224x224 angry 0.96, fear 0.04, sad 0.00, happy 0.00, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_131.jpeg: 224x224 angry 0.99, sad 0.01, happy 0.00, fear 0.00, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_130.jpeg: 224x224 angry 0.98, sad 0.01, happy 0.00, fear 0.00, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_129.jpg: 224x224 sad 1.00, fear 0.00, angry 0.00, happy 0.00, 75.6ms
# Speed: 0.9ms preprocess, 75.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_128.jpeg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 4.4ms
# Speed: 1.0ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_127.jpeg: 224x224 angry 0.99, fear 0.00, sad 0.00, happy 0.00, 4.4ms
# Speed: 0.9ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_126.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_125.jpeg: 224x224 angry 0.99, sad 0.00, fear 0.00, happy 0.00, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_124.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_123.jpeg: 224x224 angry 0.99, fear 0.01, sad 0.00, happy 0.00, 72.3ms
# Speed: 1.2ms preprocess, 72.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_122.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_121.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_120.jpeg: 224x224 angry 0.89, sad 0.06, fear 0.05, happy 0.00, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_119.jpeg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_118.jpg: 224x224 angry 0.98, sad 0.01, fear 0.00, happy 0.00, 4.7ms
# Speed: 1.0ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_115.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_114.jpeg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.6ms
# Speed: 62.8ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_113.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_112.jpeg: 224x224 angry 0.99, fear 0.01, happy 0.00, sad 0.00, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_111.png: 224x224 angry 0.70, sad 0.30, happy 0.00, fear 0.00, 5.7ms
# Speed: 70.8ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_110.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_109.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_108.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_107.jpg: 224x224 sad 0.81, angry 0.16, fear 0.03, happy 0.00, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_106.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_105.jpeg: 224x224 angry 1.00, sad 0.00, happy 0.00, fear 0.00, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_104.jpeg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.7ms
# Speed: 87.1ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_103.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_102.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 80.9ms
# Speed: 0.9ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_101.jpg: 224x224 angry 0.99, fear 0.01, sad 0.00, happy 0.00, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_100.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_99.jpg: 224x224 angry 0.98, happy 0.01, fear 0.01, sad 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_98.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_97.jpg: 224x224 angry 0.99, sad 0.01, fear 0.00, happy 0.00, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_96.jpg: 224x224 sad 0.95, fear 0.05, angry 0.00, happy 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_95.jpg: 224x224 angry 1.00, happy 0.00, sad 0.00, fear 0.00, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_94.jpg: 224x224 angry 0.99, sad 0.01, fear 0.00, happy 0.00, 4.9ms
# Speed: 0.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_93.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_92.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_91.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_90.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 8.0ms
# Speed: 1.2ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_89.jpg: 224x224 angry 0.95, fear 0.04, happy 0.01, sad 0.01, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_88.jpg: 224x224 angry 0.98, fear 0.01, sad 0.00, happy 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_87.jpg: 224x224 angry 1.00, fear 0.00, happy 0.00, sad 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_86.jpg: 224x224 angry 1.00, fear 0.00, sad 0.00, happy 0.00, 4.6ms
# Speed: 70.0ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_85.jpg: 224x224 sad 1.00, angry 0.00, fear 0.00, happy 0.00, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/angry/angry_84.jpg: 224x224 angry 1.00, sad 0.00, fear 0.00, happy 0.00, 4.9ms
# Speed: 72.8ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
#
# image 1/1 /workspace/testImg/val3/sad/sad_75.jpg: 224x224 sad 0.99, fear 0.01, happy 0.00, angry 0.00, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_74.jpg: 224x224 sad 1.00, fear 0.00, angry 0.00, happy 0.00, 7.2ms
# Speed: 0.8ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_73.jpeg: 224x224 sad 0.93, fear 0.05, happy 0.01, angry 0.01, 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_72.jpg: 224x224 sad 0.94, fear 0.05, angry 0.01, happy 0.00, 8.3ms
# Speed: 0.9ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_71.jpg: 224x224 sad 0.70, fear 0.21, happy 0.05, angry 0.04, 5.4ms
# Speed: 54.5ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_70.jpg: 224x224 sad 1.00, fear 0.00, angry 0.00, happy 0.00, 4.9ms
# Speed: 2.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_69.jpg: 224x224 sad 0.91, happy 0.06, fear 0.02, angry 0.01, 5.5ms
# Speed: 75.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_68.jpg: 224x224 sad 0.98, fear 0.02, angry 0.00, happy 0.00, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_67.jpg: 224x224 sad 0.96, fear 0.02, happy 0.01, angry 0.00, 79.2ms
# Speed: 0.9ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_66.jpg: 224x224 sad 0.87, fear 0.12, happy 0.01, angry 0.00, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_65.jpg: 224x224 sad 1.00, fear 0.00, happy 0.00, angry 0.00, 4.9ms
# Speed: 0.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_64.jpg: 224x224 sad 1.00, fear 0.00, happy 0.00, angry 0.00, 62.9ms
# Speed: 0.9ms preprocess, 62.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_63.jpeg: 224x224 sad 0.79, fear 0.15, happy 0.05, angry 0.01, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_62.jpeg: 224x224 sad 0.99, fear 0.01, angry 0.00, happy 0.00, 4.4ms
# Speed: 0.8ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_61.jpeg: 224x224 sad 1.00, fear 0.00, angry 0.00, happy 0.00, 77.9ms
# Speed: 0.8ms preprocess, 77.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_60.jpeg: 224x224 sad 0.98, fear 0.02, angry 0.00, happy 0.00, 8.3ms
# Speed: 1.2ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_59.jpeg: 224x224 sad 0.85, fear 0.09, angry 0.06, happy 0.00, 71.9ms
# Speed: 1.2ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_58.jpg: 224x224 angry 0.67, sad 0.18, happy 0.15, fear 0.01, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_57.jpg: 224x224 angry 0.57, sad 0.26, fear 0.11, happy 0.06, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_56.jpg: 224x224 sad 0.93, angry 0.05, happy 0.02, fear 0.00, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_55.jpg: 224x224 sad 0.54, angry 0.20, happy 0.18, fear 0.08, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_54.jpg: 224x224 sad 0.89, happy 0.10, angry 0.00, fear 0.00, 4.9ms
# Speed: 0.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_53.jpg: 224x224 happy 0.77, sad 0.17, angry 0.06, fear 0.00, 75.1ms
# Speed: 0.9ms preprocess, 75.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_52.jpg: 224x224 sad 0.40, happy 0.36, angry 0.14, fear 0.09, 5.0ms
# Speed: 88.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_51.jpg: 224x224 sad 0.69, happy 0.28, angry 0.02, fear 0.01, 5.5ms
# Speed: 1.1ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_50.jpg: 224x224 happy 0.97, sad 0.02, angry 0.01, fear 0.00, 77.1ms
# Speed: 1.3ms preprocess, 77.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_49.jpg: 224x224 sad 0.61, angry 0.35, fear 0.03, happy 0.01, 4.3ms
# Speed: 1.0ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_48.jpg: 224x224 sad 0.86, angry 0.14, happy 0.00, fear 0.00, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_47.jpg: 224x224 angry 0.83, sad 0.08, fear 0.06, happy 0.02, 4.5ms
# Speed: 0.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_46.jpg: 224x224 sad 0.84, happy 0.08, angry 0.05, fear 0.02, 5.4ms
# Speed: 61.7ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_45.jpg: 224x224 sad 0.57, happy 0.34, angry 0.07, fear 0.02, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_44.jpg: 224x224 angry 0.88, sad 0.08, happy 0.02, fear 0.01, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_43.jpg: 224x224 sad 0.99, angry 0.00, fear 0.00, happy 0.00, 5.7ms
# Speed: 62.8ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_42.jpg: 224x224 sad 0.37, happy 0.30, angry 0.30, fear 0.03, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_41.jpg: 224x224 sad 0.97, fear 0.02, angry 0.01, happy 0.00, 75.7ms
# Speed: 1.2ms preprocess, 75.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_40.jpg: 224x224 sad 0.93, happy 0.04, fear 0.02, angry 0.01, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_39.jpg: 224x224 happy 0.65, sad 0.29, angry 0.03, fear 0.03, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_38.jpg: 224x224 sad 0.59, happy 0.37, fear 0.04, angry 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_37.jpg: 224x224 sad 0.74, fear 0.18, angry 0.04, happy 0.04, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_36.jpg: 224x224 sad 0.74, happy 0.22, angry 0.03, fear 0.01, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_35.jpg: 224x224 angry 0.54, happy 0.33, sad 0.13, fear 0.00, 73.2ms
# Speed: 0.8ms preprocess, 73.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_34.jpg: 224x224 sad 0.91, angry 0.05, happy 0.03, fear 0.02, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_33.jpg: 224x224 fear 0.32, happy 0.31, sad 0.30, angry 0.07, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_32.jpg: 224x224 sad 0.99, happy 0.01, angry 0.00, fear 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_31.jpg: 224x224 sad 0.77, happy 0.14, fear 0.08, angry 0.02, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_30.jpg: 224x224 sad 0.63, angry 0.23, happy 0.08, fear 0.05, 4.7ms
# Speed: 0.9ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_29.jpg: 224x224 sad 0.95, happy 0.03, fear 0.02, angry 0.01, 73.3ms
# Speed: 0.9ms preprocess, 73.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_28.jpg: 224x224 happy 0.84, sad 0.14, angry 0.02, fear 0.01, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_27.jpg: 224x224 sad 0.66, happy 0.25, angry 0.08, fear 0.01, 5.0ms
# Speed: 0.9ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_26.jpg: 224x224 sad 0.82, happy 0.10, fear 0.07, angry 0.01, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_25.jpg: 224x224 sad 0.94, fear 0.03, happy 0.03, angry 0.01, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_24.jpg: 224x224 happy 0.35, angry 0.34, sad 0.26, fear 0.05, 7.6ms
# Speed: 0.9ms preprocess, 7.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_23.jpg: 224x224 happy 0.73, sad 0.20, fear 0.04, angry 0.02, 5.1ms
# Speed: 62.9ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_22.jpg: 224x224 sad 0.96, happy 0.03, fear 0.01, angry 0.01, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_21.jpg: 224x224 sad 0.79, angry 0.11, happy 0.07, fear 0.02, 79.3ms
# Speed: 0.9ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_20.jpg: 224x224 happy 0.56, angry 0.43, sad 0.01, fear 0.00, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_19.jpg: 224x224 sad 0.44, angry 0.25, happy 0.23, fear 0.08, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_18.jpg: 224x224 angry 0.53, happy 0.21, fear 0.17, sad 0.08, 4.6ms
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_17.jpg: 224x224 happy 0.54, sad 0.20, fear 0.19, angry 0.07, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_16.jpg: 224x224 happy 0.47, angry 0.20, fear 0.18, sad 0.14, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_15.jpg: 224x224 sad 1.00, angry 0.00, happy 0.00, fear 0.00, 74.5ms
# Speed: 0.8ms preprocess, 74.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_14.jpg: 224x224 fear 0.39, sad 0.24, happy 0.24, angry 0.13, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_13.jpg: 224x224 happy 0.70, sad 0.25, angry 0.03, fear 0.02, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_12.jpg: 224x224 sad 1.00, angry 0.00, fear 0.00, happy 0.00, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_11.jpg: 224x224 sad 0.60, happy 0.24, fear 0.13, angry 0.03, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_10.jpg: 224x224 sad 0.90, happy 0.09, fear 0.00, angry 0.00, 4.7ms
# Speed: 0.8ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_09.jpg: 224x224 happy 0.40, sad 0.36, fear 0.17, angry 0.07, 4.3ms
# Speed: 0.8ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_08.jpg: 224x224 sad 0.60, happy 0.38, fear 0.02, angry 0.00, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_07.jpg: 224x224 sad 0.99, angry 0.01, happy 0.00, fear 0.00, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_06.jpg: 224x224 happy 0.47, sad 0.43, angry 0.09, fear 0.00, 4.5ms
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_05.jpg: 224x224 sad 0.67, happy 0.27, angry 0.04, fear 0.01, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_04.jpg: 224x224 sad 0.93, angry 0.05, happy 0.01, fear 0.00, 4.8ms
# Speed: 0.9ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_03.jpg: 224x224 sad 1.00, angry 0.00, happy 0.00, fear 0.00, 4.6ms
# Speed: 0.8ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_02.jpg: 224x224 sad 0.62, angry 0.27, happy 0.10, fear 0.01, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /workspace/testImg/val3/sad/sad_01.jpg: 224x224 angry 0.62, sad 0.19, happy 0.18, fear 0.01, 4.8ms
# Speed: 0.8ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# YOLO Accuracy: 0.903
#
# Evaluating DeiT model...
# DeiT Accuracy: 0.811
#
# Evaluating Swin model...
# Swin Accuracy: 0.944
#
# Evaluating Inception model...
# Inception Accuracy: 0.363
#
# ==================================================
# MODEL COMPARISON RESULTS
# ==================================================
# YOLO        : 0.903
# DeiT        : 0.811
# Swin        : 0.944
# Inception   : 0.363
# Visualizing predictions for 6 random samples...
