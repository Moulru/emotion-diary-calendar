# %% [markdown]
# ## YOLO v8 모델 사용

# %%
# 라이브러리 불러오기
import os
import random
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image

# GPU 설정
DEVICE = 0 if torch.cuda.is_available() else 'cpu'
print(f"✅ 사용 디바이스: {DEVICE}")
# Out:
# ✅ 사용 디바이스: 0

# %%
# 경로 설정
PHOTO_DATA_PATH = "/workspace/datasets/dataset2yolo/photo"
DRAWING_DATA_PATH = "/workspace/datasets/dataset2yolo/drawing"
PRETRAINED_MODEL_PATH = "/workspace/models/photo_pretrained_yolov8x.pt"
FINAL_MODEL_PATH = "/workspace/models/drawing_finetuned_yolov8x.pt"

# 하이퍼파라미터
EPOCHS_PHOTO = 10
EPOCHS_DRAWING = 200
BATCH_SIZE = 32
IMG_SIZE = 224
LR = 1e-4
PATIENCE = 7

model = YOLO("/workspace/models/yolov8x-cls.pt")

# %%
# 1️⃣ Step 1 - 사진 데이터로 사전학습
print("\n🔵 Step 1: 사진 데이터로 분류 모델 학습")

results1 = model.train(
    data=PHOTO_DATA_PATH,
    epochs=EPOCHS_PHOTO,
    imgsz=IMG_SIZE,
    batch=BATCH_SIZE,
    lr0=LR,
    patience=3,
    device=DEVICE
)

# 모델 저장
model.save(PRETRAINED_MODEL_PATH)
print(f"📁 사진 기반 사전학습 모델 저장 완료: {PRETRAINED_MODEL_PATH}")
# Out:
# 🔵 Step 1: 사진 데이터로 분류 모델 학습
# New https://pypi.org/project/ultralytics/8.3.159 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.7.1+cu118 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20147MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/datasets/dataset2yolo/photo, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/workspace/models/yolov8x-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train21, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=3, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/classify/train21, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /workspace/datasets/dataset2yolo/photo/train... found 5756 images in 4 classes ✅
# val: /workspace/datasets/dataset2yolo/photo/val... found 1440 images in 4 classes ✅
# test: None...
# Overriding model.yaml nc=1000 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   1646084  ultralytics.nn.modules.head.Classify         [1280, 4]
# YOLOv8x-cls summary: 104 layers, 56,146,964 parameters, 56,146,964 gradients, 154.3 GFLOPs
# Transferred 300/302 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.5±0.2 ms, read: 265.7±43.3 MB/s, size: 3112.9 KB)
# train: Scanning /workspace/datasets/dataset2yolo/photo/train... 5756 images, 0 corrupt: 100%|██████████| 5756/5756 [00:00<?, ?it/s]
# train: /workspace/datasets/dataset2yolo/photo/train/angry/00hj57bc2be60739b1b9f99316a3a11de5febe993b093876bb33d7bab900006ts.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/00ll57ed4d58f3e6c766e65168fc704d9e43ca0b1de8dba8927517b474f083s8x.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/013320f6c6aa0752eb2933111106c9bcbfaaf62b4168626b0a1f3288836bf1n3l.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/05bm462b58f3e2803222f677525c32f112fd1c5b753346a01f228e9b026657qhq.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0aul95639d66c4bb678bac9c296566384c4708131675d709f62071c2913728q1y.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0dji06c60ccea88d675db12142cb60f621c567c876b97fd6aa39be04e26e69x8l.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0h1d057312e7900728373851d4b2611b2b50922987298f87ed0caf1b76c429ndq.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0hee6d13b154caa765569e2307f0c1b16e7fe9f072eef1ffcb1cc7b72ef003bwj.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0jsg06048a28fde3caad404f93dec397e5c579e83c1c2ced67c346c93d48dju4r.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0nkle0e27387c4b3053260940459c0a4f78cbb54c47afc140731c46e78167wruk.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0o55fafd3a8d2507da81afca2a280a3eb39c506ce72f2e825a88b7a7ba3dd17ob.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0oer3a498c4f88be314dd5d7767139a164f36f864df1196c9819684cf3121wlaf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0qym4a600bfbab0b0ef03493544abf4d0989bbabd77d40ba4d5d45e90b5d46a3u.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0sov982b1473834c2881a41794c9b41b387c8cbc754cb79b997984c481338wa6d.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0ss4db2b8d0a0f26d28870f2cf481aeda24af83dfa3fbada26cdf1d196419dtu8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0tj25997789690fd794f341e6a4a67e36010101688bef0516f6e7de1715667qx9.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0tvxbd5bf0bb595d8cc9de9bdebbd316c1dcdeb75d92a04bd752f8c3bb6ddg0mx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0uflaf6d55475d9b197f0f9f451c05f45184eacf046b34c474795340bfe49qhc0.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0vidbe3b5ecb6fb5a86fcb4f5ddbcf113a7e4f42bdbb3bbdc1ed31b014cbat249.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0wvi5391531eb733275e53e06f10e77486fc5fc35b3cc7c6484f250aba337i0y5.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0zc7d4f5ec53191cf49c341f9ba4dbbc2ebe5cce3dcc30444fd3b2abc7e2248ce.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/0zjf211d448c74c74a64053cdecd3db76457e4112bb5c54a545f60bde3482wntl.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/10rr41157345c36184340609f95aa863b1c8848c46e663a9f0fa13606043e0xmb.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/15bx6506f8adc9676da3ab59f44b086cfd569fa753650f1593b3e677dbfc3c31j.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/15s170b4e791eed247a8da1e7fec80574e50b373641e478dc28a94e8da7f10bwy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/17gc7f456120101bb0f646517df2e35957f011da690f60331d01e7f778019yz7h.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/193q17dd260524fd897bd38982737876960b3696698cb3a69b59787295448ovk9.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/198296de165e77fac2e4bfcb1999db8126db76b794b71bcd6cda407bbb6ecme77.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1asj6bd1eab3abaac88c44c8bc04e23c9427b84dd47eea4c4049966d48446zbzi.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1b7nd702a7ffeff03f3e13faa7e1b1e13ad73f0a2181fe93e011311a373ea70wf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1ch66844e6066d8b9860617a9a857034ceea740bcc0259f0e03a873367ae6so6w.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1eqkba36bbc72f149aacf544db54c51274574671fcb4bfb3acd791f27c2d7zjzg.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1gqv456fb8bef0250d04818d942495387d597186e430fd57b735851b4fd385vh4.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1h14b8f62344cf3347fbf14f56d059663c901319f9fcf99b6a935659ba966g1k9.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1lpla79e0b1081443b7dd04af4aa4b9d9a3fd9ef4a20febeab3bb02b6a147bulf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1m3m2a5a45584a9922c0ffd33f4844099d769f0c33b9d8929145597e40aa2i0s3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1mgv80d81ea75e7ee0a27496b2103e08073776be3eab426aae2e072017e4a3diu.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1n0oa2211b2b608a7bdebbf3f973010b77b69bd2ba0db239632dc0189da35lcqn.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1nj644b9cbbecc9c5ac4a72544b2a5ac24858b7ca248eb554c39464bc79a9dbk6.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1p75a443a57707b1ae75813313877ab651bb67fa94193e02bb1cac63b8b5cl1kx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1tkb37c1941400ebbcb79c3d238f4a9b7305f090317166025e254ea907f67v5gh.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1u8i967579529030690633e3699a5033edd514afdb510180d30b2c5a830073keh.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1ur05100b0c41c2c180004c1bde0c001d682c90580d0cb184062051a68600lon9.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1vyf27403b318f9e3744b9a9c794d10d74d0434809b2f6b098ce9ddccddbb900z.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/1yo5d494e6eb845c3c58d530853439947e3e3c65eb408c44d938b02a4fb3emcik.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/20f0905933af6c37c9c70a43cb9aaca1239f1528e6bf53479a30f5c6b11acet79.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/23ds340eb59f21f2912271a74790f2427c38219211827019268ec19e2237495uk.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/29u351308d544aac43cbbcb18cd345b20419ee097a8c08b7eb2ac3aca57efi5hr.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2ah0453fb504fa4331b34c2ec0a22645b220022e44cbf8b2b8b48650024ffpsln.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2dla2e0533c0a4566dcdaa71d0fdb4624d355b4b9145d4410c436ed73f5f5c4mc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2dsfb06a4eb0f683743be548a479a036149574166645b130b1a04ca074a0epgs7.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2fhec84a625e6d53b47856dbcd4ed5f8bc5b38b99bca6c96b35cc4559fce7gwi8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2gpk4c94d6c5d574a601527f6abb3ab45747dac34d51b0c79158a286d06aajycn.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2gpz9c9f374b1db174f21f6ffffbbb11f0eee7bae7eff0fb2039e1a514d47d7no.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2kj5024fd462a9f2fcd9f99b3dcba2f7fba022449050d99bfbfb3cbfbc83bgmeh.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2nsm73ae6ef75b63c0d97063d88cabac717718b6dd62e7c5a2aceeea8ae7b3288.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2p7m7cfced272c8f7cb555e41c478c8eec26eac5f88dac877c70e66b7f717darw.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2q1a6f66024b06664c955c68b9f64ee850015551f8da0b8e7d44987d49dedremg.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2szaa49f529859525fec69b164bbb975bfcfd76b97feb85e9f152295fcee74xde.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2tby14ba67fea06c15c1c19c15c47b0a7c90bbe3f0607657c630df1cc9a64yo1v.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2yctdfa9e8b2529443c5bc3bc90b0186ce0a4ec9d540bc0410cb30bb0fefck0so.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/2yqh14d6183189212b6a9aa10b11f548d1f513f4aa3d76a03603ad851fe8469kf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/30zm36c6ba7da4cca92a4c56e9155b6a16f37b779a7ac54bf99c5c64a66916squ.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/347ca65c9b7e263f7e0e92bc0f2ccf6c71441ca7e5a1f35bfc68510e7897cvkdp.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/351a2c4c112d616e37933a366317676fed8ccc8e6dad2be8f622f6c7a6e6cguw3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/38ey373fc3c7337b878486a7547bb5b373b53475807cb23999fb9783b39390nzp.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3bfj0080a0bb8340b6638009e4f69b6340658f0fb1aa68dc861a60fcfb4314wgu.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3ccf5281e62e463da47556535d3621f3ed39f6dc9d464233e4468558caf669oxr.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3gc5ef2683dc50cb8d186bbbc03c8cc26e8105b7e0cbcbb1e255d9c645fb5e3g8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3lld49ceeff5fa125104c9e42ab15f9f4b594fe3861c91c54a99c5dd9f4967xir.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3lw0aee0cc82f7982fc0a20706105bc917d30b90237be6c8cea0a306330dbi27a.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3m8k7d1f868aadbfa5bf41407bdea4f4adef0a639bddba1a444dda04d39b0z6ex.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3mt898d31e090855a3a26f3aabfffc2ecf6dadf92879ed4131ee6a832cb987di2.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3omb84e87fe5f785bae6cc55a2a8fa995b6edfc353c7d865ff353dd0e74c1gbst.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3p0gd2290afd21a168212f0a39fa951cdc5b2a6aa47b0e20133818ad9ac017hnh.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3qok2418568c2784971b7145f27b762277518a6552b5aa6a3e16286667746awiy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3qqp47c6542b0be3c03a671c033a918facc8ac33ac5a0b97d1863c41136abv1wd.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3reu0ef060fc2a7a72fff49f0729ae4525ac93f722f044df27c06d69e7982s01c.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3saxb928e5f5ac94cf9c649cbb8b5eff22bfb92b9fd82d8e5d4cc6cbf4949rlpk.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3snrda36cbc5554f4baf5755cf91abab69926ffef79e8e3034854aee57b34vcyy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3sxe131f78c889c73c7cedf081ffc547f8bc117c1c5d5d79cd1d1418cf4a3gqpc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3wet68486f7fa1d5b75d9b84cbb9595ea9e963c05769e913900710c783fbcyf08.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3wi3057be4052df5bc31408be1ad118eacfbc24ebfdce21bd3ab1800cd2acr0hg.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3wqb76e46dcd0dddd8890299296a822800cc326048206c82ccc2366bb9c6ateh4.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3xce2d7fc03fcedf00bf88a3cde0111530cde1730577fdf2381d257fd1a82kl99.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/3y1gbe44a6171b3a58264e1a53aa7547d6951216693ebc44155aa37ee458a8ld5.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/42aw3714b6d40e44120b4a42f2e83364f42f13d7417464189652912a3a75eorq8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/43ze18eea51124b04ba62d4aafa8a413e83732d23a10c8abbe1a20c0b48acthar.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/463aa266d7f3f96f5f4f447f434da6856109371430043a2a21f8bf3a1674djhmn.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/467p19989eebe589e1de42a87dac9e21c2e177276dd2eee3aaa79fad1f93bg107.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/46qh221631daf7a2aafd7adad5334c3e8423ac84424381a1eda231dc44183c15u.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/47bfc3db7c6cda1ab5b7531d5bb21ed112e38a9e7bf45513f3a233529111fcmsy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/48hl2244fe8c7de37c134006b852c9351ed287c986126ebff76d454c29f143q7e.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/49bu0932b7e75522072552aefa207aec3539004f52f359fe5a275772ef5a0m488.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/49er34a8bbb1cc810541a3aef31e8d0e6fa32a3d9363b333143a935a6ed0943ws.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/49r0069fe8c97e8cf35647fd5080e78566195577605648c673890d705a6f8v7d7.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4a3m7a899ee2f8357cf95764f2ae91369bf3deac6ee358978c36ce32b6af5pyb5.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4h26985cb05020953711905dab22233cb5b2289078520ba05b5fb3ec575fd2wcy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4iece33c1a5b965c7be673433575bf9af3ccce6e647c313343cfa0a8a31695nlj.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4itae994a945cb98e38104738f937e3397fc381355e345543ee2eea93f935oexp.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4ka4ae1af4710f7842edbbafdbe8f2b8b8eff6bbaaa04babe180b7bb4bab7xp9e.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4pfie0ba9c40928f1b82bfcb06600c0a901b5069feebbded2da080be4eda41lpo.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4rif5a1aaba5c98cee60d9969c564bbaada0d1c0e6c756c9fba7715cdd4e2gf85.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4w0rb0117277ef02235e3fbb2a543a47d0f0a488deb2703203c4100b1a63a083j.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4xhu03a3146360a6c8f656993b1d7c426666c1e16089dffd6d3ee019df30dfodu.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4yju9ed3a8fe92aaa9552abc1fa73e08c38007977bfa2172a71c08ca90653l32l.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4zky5304d4357a37f766fc3cc475c19883d2eaa0f78e7d7fdd309d74133c3nd5e.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4zqtdaf7d44c0e447c0499c701c4c7ca753b73acd36ef3f8e1ce1c09056bc02ty.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/4zr222500f8419a4e7670deccea466769a8480495e4a8264ce6d6d85478df23o8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/528253019106737c4cfd317591b746fe5577519bee749ecfd0e9760d355f4n6ai.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/53gs08dcd7939c5bd70ef3ef7d52c0f09c8fd0bef055c48879079fb3747d3i3a3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/53xw53a6bb11886cdaa03e6035cfddfcfd28d86cd4d7a1424e1e85fb1e1a79yl1.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/55uz14c8d57b8eecb731b5ccc49fc1beeb2f85273e2cd945b8ceb89cee876qq8b.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/56gz2b5d7f85e5224f8c4b8ca22b822cc74684a2623cccac4ecaefa1e3a5aj5op.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/599l03efac5ebbfe5df17b3375b48e3475cfcfbab7ce92056c00b054310705t7t.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5c3a334d10cb2e249b6ee1fdf3023da1f019f072c82a98a2a88f9d911d1d3iabg.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5d9p7c6af42e78f66f511fcb3ff18c961212e8fab2b8d942b10281458bc95nflv.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5eed7d9798c1d2f0d0150dedd1370e93f9a78e3dd1e160d34f6698aacdd54g4oz.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5fux1b0fa19796910597ba6901d70a09129a6c91e96eb46e529471e9c12e7pbse.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5g718353eaa561ab377f9799f44af3d1391dbf8687c568ca88386f6bf3186utu8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5ghtbd102e81b9c9d14d90060c127ca1813021374c3c33c5b138113910131li0j.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5iss8a649b0be5755aa5f68ee808eb3f16e0b9960eeab2fb5af6be12d8d09aqne.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5k3cad537790d316e8690156d67aa60d160a81e3bf56d4ee81d101340a5333i22.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5k6p111826008812f37561f40882616b260851344b8a510d8596e78c13d2em38i.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5mgv1361135fb1bb89dccdf8d0505c5795b6955cc11cd86b3db5bdd7b5688l4fd.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5ou4f8016cee984c4f147f72956229ec87d5e5f126c8fe28bafe8dfe404f90tmc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5pa7b4bfc84fa6814acec9f30bda7fdd99faf41ca80dc805bf44fbc63c5easjyr.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5pz3a86fc752f6d432a5c085f69f6b368848c13014a2312953d38327a5a4fv69d.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5qp35922afbeff83f916d8625e2cb9584d9fcbf7cc5cf3237f83f2caaf18bgtyb.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5tjz33c64b81cbf4ab8341c0a4324fe16814a42314abac4ff5ee6e4b21f82ze5r.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5tu6ebdef70fd7f737a3e1e14f20f17942f1117b902e17177734e716f281akuc5.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/5wcad017cf0c86d46d88611637414816564746fc78f2c9dd6f786ff9dc635cbkk.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/61eg37692ee55da6f407a2776be79020a760870e7177350e603e24550c7b7m57c.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/651pc233b6c4b641ab984463848881c3cbb06387ca08814b384cb1b96b112jjrf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/652u8448b8fe28dc21a110cf72f83be87bafe0787fb8db374ea148b22321dp99r.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/65rsfe402042f34319e10128c1ab9614e2f967690a64a0016f2c49ff33fe7sy3z.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/69n0778e110a144a07142599186cb71f3683417e0a366211640a3787e68e0vruy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/69t9ccc1b002db00ff5be1735266c0b5bb5462db9c6ff0836f18f32dea160h1bc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6alyb7ebb5b9d5dbb093d54edc8dd7d95b42269aaed35ac0dddcd16aa6bc8qzma.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6axgbf2a0ffeead1e0285c0e6d2552b0bffcd162252c31c6507e2222c097bphh5.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6bd60c185bb10c62b79d753c02c31c627d76293b67bc3b84cdd83701bf163rlwa.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6c7kf43e044ae2b3448dc24f2b9c49e7f026c9fa28eb2cacbce202f3295c7t14q.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6f5ib101229404cfa4bb6501e5cfc99bceb4ef2290f6ba714bbbf4afbb47bd50y.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6f7230024383c24f2f98f9d6ee32d67e85e78ef3e59307580f344c99cf05fzt1v.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6fie0720d44003c0b24b034594bbf8ea26cec100fc640607d8ee7f4dfbbbezl0n.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6hnmf10d3da813c33899f9d6fcdff355fd8a6b23d0758e686032c3c54a9552iuy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6ij2552f4f5c8b8f885cb9541696d23cf9bc307288b589555ad4f3f88365916df.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6io429357a004d6e9d9858e9c97c993a786334034343647e563909a5e60a3s96u.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6l9p5fb303834db58f5a659ff8605497d67367d356bb8624b3367bbb348828a6b.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6maqba3c3fc5dc434b61bfc59ece532f0a4b974246fee5cf4d6b46604ce99ik5r.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6nab4cfe5b570bd992c83d741cdcec9c7335e9bd8bd7187bda58cb13bca84k8y0.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6off739272e6b656eeea59d09542869bb8605c932528046e29928500bfc2aoacx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6oj439e3fbcc52759fb3093035b7c0ecc55c93543dae63ec1162f5f6bfc6e481l.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6p6bdc1f95df3774d7af89646346c5c9c236ba466ce1c14f981706fd84a996pe3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6s3n93f266a49a6dada1a28cc2ba43310a6b933d176de9ac3698735eea3c61pll.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6thye5527cee2f3e59e8ce2d36656d6e8204c437c46fe3f7562683762365654nm.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/6zs8dc4ecaaae1f7285703ff1c2e8333fa28707325efeeca1a18a631d2942zfkn.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7089f2fc40fdfcf69ad4bba20e2b241c687ec323a94f22abacd1bccc449204pz5.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/74csd92bf767323e7739045942e26ff99f0fafd4c989056437deec610477ea5cv.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/75hdaeffa8487ab0fb7c3e7fcd0f00d8cffdfe31fd03dfdded1bf8f7f3127grsn.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/767ed051e10d463080b39e5efdf0e70d3165597605c575399ea1395ab60bclfbc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/768e6700171288f78e02d813517e1eb36875508170f5506b81d5365aa5e823y5p.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7b7m77161ca00dc89041c7b2682fdc087f1cf9320748a8ff6b81c6f6d787ek7qx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7d8p36d729556657b731c54b847382b82bd96bd5bb93f6ca9cb859d090951xbgj.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7dch6f3696ae4b5055bea4632994f4ba445c92ee943a060e635a4db502a3f2ixg.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7fx58e953e45a901fec20a0332bb69d6ffe090be73dfded40c963c5b703a61hvt.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7g9wdd6ee6a6d56aa931fe1dac417d2562886803a6aff76c9b0640f94d9caso79.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7h0p4c054d4bbec0b6591737174c5d79d2c0677914725fc449e223271db190sbc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7i2sd5a5209335354992e25d3954f9e223bbe79f215a020fc73be1ce0ee29deqx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7im965b9dc879ff9291269f0f8965d3f560595f7f3a571909a3877fe7c3b14vxk.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7j8g8f0d75c68c342c387887740d7289102d87973b36373669c4794a481d6ot2w.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7l70fb0200a1d0904c2cacbefdc431c0493399ff3c3dca1b1b3129990ff83rrwl.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7lm099357a2a98d93c3cb0b19a91e37eae5d1a2a32ff9d5f1c95172b71bca5f48.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7mvea9a9ada848dd9faa82ba52a3c52520282f32ad92f332d92a305a9725968wx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7n92f7a4ddd912048e4f952df769ce1b1111d731dffbb11d9ad160bd203c9iy3e.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7p1ib051463f7d9894477e222b9a5f86543f13c547713ce8b41e70e43fe06vrdu.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7ssk1c664133161ac99eec36c869c913a2542837ef95c29d4771ea6a493aejsow.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7ven8a800ddd60d88664c0acb0168d88add0628ad90d38363d6f22dd9ded7cl12.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7vjz98b13f9db6ab9e34624161f1b180bb9767c41f40af6b11ba3bfa196b11og3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7xixc822f226e4bd69a1aad0ca892e2c8ee26aaba68d3296b2e241cae3e17kegn.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7y19dee1963cd37a3e10411b9770c1e5e1fe1b4146e06480efbd1aaab444e7a4c.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7yht0af78f7b0b0884f3c06f03301ff42314a98172708cf27d0d5716b67f1dvy7.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/7zyr75c79997789b019433b84951088f73fe939f8f889f54f822d741f8318c67a.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/827eb3b78bfef2e1abfe48772e298f99f2175f8ff2b96eed26fb3afb1b21byp7g.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/89h64f30d009a6f5a99c10439106683082cb8b75669aa15c08f6169a68944kicq.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8c9pa971f8b2a26da737d28204f7a801a3ffd7db0013d8640a8c2bdbdfaabkgpb.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8ehg0c36802c395be2cd7d3af33cfec8a5384394afc7e11cf363d2e510543qo58.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8ffk102c7a5e1701e5e03d158aa126e8b33b78fadf5e2bfeaa207112fae7fpv2z.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8fiib08b3bb46957a51401980285d829098d06babd4cd89536d995fd7e990gm44.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8fmff95f73e13cf7095ccbbb6ff0c507d61becdcb62fcedcbf3e3c0506d33ddbv.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8fnh87af9cf4332676685875528703712b0d0374860186064e48b167e8a38nh0l.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8hdi42c2c727f6b6a3572dc6bda32773533b3e6d5c6811f3b8c67d7f7c725wv5v.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8hj3c6f359ee8aebbe754d45655d77e55a345c53d5abd7d6b64ded9433554itl6.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8j6jc6cb71e66ce03c38bd4eae0dcaf117ad00000007e27d20a8abc090701ynzc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8jmb8336cf66f661313fa215d5e198f617383b560d6eb64d08925bfaad6dbmda7.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8jnfcf680aacf8054bd2278828ca3e3352448cd6caa272ecf7dc5d006f7cbo65e.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8ju0661defb6dd46179f8785cd9ee6cd17127722ee4d9cbdbe7b7a54b15695dut.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8l9q933f997c551d029379c87c17a78959307833c81aef069a7d685d1d4d8fruc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8oak277cdc4b954ce55c355bf505bda4adba40c471ac73be4cf5b174d0b24jcki.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8ogfa38652ea8c683e6e77ce6a635a586dec07484a7a8428ed5ba78e3d22cjubb.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8pij3c93139365b41b4082402fe191929bd6e8315745411b99f15d61488114bra.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8pjm940e2fb57922b6689573879095df2265754145fa67429e9f006926f56pr0r.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8qnea6a7774d0d66422d00f6c022b77e3dd273f69d78899dd7848d7fe0726ynen.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8shf7531f1aaa11ab4e743a25d2dcbc62705c7dd764262d42174be55ed26d3ggs.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8sknbd1be5c2cbcdcf1cc10a715714b3debe4eb58fe6fde16f31fee45e4b3fk1u.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8tz43192246b5e9c93cdf7b92cc1687182b16b5f2264868c242f9196ecd2c2ma8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8wfs31aab9d4d76a384073aaf32f4973d34ff1bd937477d20ba73b4d75a27iia3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8wy3902968597f41faa0f8d3dfb9e99f487eab4f62583d97753ded7fa6d1fof3y.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8xyhb5b3ae4ff8d3fa803ca553bfff598f66b9346539e1f700e9fc872c1b9b19k.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/8yrb8eae858d13c5dea60e5fe96cee77caf287ea7a17a6c5d79e318ca8ef1ymds.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/918202ae99e85f58035e59ae77f450c6fa7be964a906929c0c79e291303d5it97.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/955g808c95ae8a6658c6b6c9ab4fece6525078dafbbc4dcc6de68cbec8b08lfpy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/972r822c5c9c0765ad2ed514d80524e186dbbecca515d254ad37d5c50c6bevl2m.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/97qd286a32d92d1af8b6450c57ed8388d5718f83d9e7616b7b797d97ee136whzd.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/98ph7d5798a5d17531f65781039c56bb000535b713209939d06755c90e105aqgq.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/98qjb7b5fb5ec1185b2388289ff3111d2bcd4665bf21e46f03711749efd15yols.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9b0b0e0c34c3aa3baf4966ccc7b9ca5a0b0e8b6ad0b497f61399c18174fc7aony.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9bbq003c20c64604fac38cfaccc04f44f47f8207aad8057024a3d303c016a061l.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9bw925c1b38a9a84a1d7133a41edae38691e236a489eaaea33985e594227ezjnx.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9gctcc26065d2daab14d5dd7a0286e101827aa5cbca602d0ab61dcdd1d461421v.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9ho8f87388666aa07139766663aeca63016a66d621348ca67581c586186871plu.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9n0s38687816f938a99649304c638a3924ff60816bbbd88d49f4afd78c8413y52.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9no0644ff2f51fb64fb5f6de829df773068f55f413f818f3df0be93ef8701fao9.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9oxy2d2c3ed895f9a94480b9bff28cadaa0585cf999a23885d3a3cd0f72a8onxk.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9phle2f57dbed8484e220aca43d017ce3682833beef0f228a04bbd48aef34sjp1.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9pv0f8269df9df55ad3d4116404852008ed8052fe171defa956616384fe9crirs.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9qym03e7676473c660ef36f0fdb6f6e9aed6bd22461f82ba6c8a3d4690091pgrt.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9rzj2ff6822f42cef0544243362f0f4f2e08fdffff9a7498469084ccffa11c8gi.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9tj00ed7d28cd735c47e4b9eadaefcd1fbba3bfe315d34152cbdf0c7cd875hg54.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9trz1c97bda4f9caf0ac2d3bc1404141a4c5424304ceadcfc847c4fc7f46cziqf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/9ygs14f4bdb8afa1e70002ead3c2bbda867e10b2ae37576a1b75167b1d1a2to58.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/a63u7751b5fd52b5bd4edb7dc9e52dddd98cf2e1afdc0d9d0751ffb5ba40cnf3c.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/a7hb94cb329f522c1c2c520fa9a7a4a80c14684042a7810c03628dc271b68bwu4.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/a7t37887710b0a6e76ffa95b7ea82ee97d0e07fa078461f9e9f917121b720d3gw.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/a8ltcf51cac02ace77caf93dfbf7a1fb04a712bc1ce1771b2b1d29cc4f2cce54c.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/a8tu372d2c94d4cee997cf1e9f094ee5bc8f39fa964ee45770d3a4caa959evgiq.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/abg705b0073aab87a78feea59a7fc42548e9f0725ac05c7fbe7ce2480feda9yh8.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/abvad4e5fedaa6099195bbc1e10b620ee3158889951140e204554ded115898a73.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/adfed271d91b0751f8b107b1aaeebe11f1ab210bbe524e7fde0eb1ff0b57e5t6r.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/aimx7da88c97158f958ccd2d8c3c8f79b957771a58a2888771d56adc7a4dfsk2h.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/aj4b255d7c28f1db557bb94bba22a6edbed31bc51fbe9dfb263258ee994e7e28m.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/al3ufe18146026fffcea10647d2a0e0403f2b1cce0ff4e6e0366a229f3f22dm9f.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/alnpc82c8a38f9a6959d48973d665460048c9ea8b83ec08fc089232b2b3291c59.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/aolh71933eb0d175ccee2f76fa4df332d6d53c1bb07968ff60fbc89ed50e7kkwd.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/aoqh4e9fe21d312fa3bdbfb1471b2e7aaefb031e4eb9a425717b1da1bc741x3hj.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/aqxp568928931ff7bdf7a908602afc56f35d9d8a6e75df870195f0e61613f7164.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/asesf8f2811723f6b93f7f71b4789b84ee7de99bb64086ff74b9b762a3cff5qjc.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/asvka4d616e918f71a53871caec631f7edb05cbe9e3898a6480a6a3ed711deaoy.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/au44005462e62588d6954e77c56bf65aba587e5887812b75ae317b18a3027m0ba.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/avfl09176f7b4f970e70672108a7f31e6378b2f81ce17460ee0cdac0276e80wze.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/avq6c037eb1c931c1a44304e4741e2d32114abdb486a3c81c3cf9e3f916069i06.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/avs821daf86a886dd15ba54a07146a6a5b1e67d5c9a326afcfe159dfca465dtx3.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/ayxm626543483cd442f1af0f66110f4e47cb5316cc38339c0af36231c1b32nc45.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/b1cbe34734870cc11c33334e02bea93ac3a3b061caab62c0df1c6b9c75430tquz.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/b1eu45dfc1fb7cc4c775e9957ba6dc437d7eea167607fb3ccd911c7e7bcc607av.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/b4jhfd5f55c8ddc2d3d685d75537097005280d1715356b1715b576c8c558b89hv.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/b4pbcfcd0330d675592c00d633bf5bf55c5d409350030d5a00ffd5558d93ab29o.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/b8m0080003c9d1ecc3eca0ffac3a07ffbcc11db06ba0c48cac0c31dfa00d0fmu1.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bah4832389d9f275b831b574ce534d899c346921a75bfb69a1a8e23fd86893n31.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bbydfb5d2aa2c6c8e46d5eb23ba0e27bb6459a8de08b9068db3c6e3dee2ae3ajm.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bdvu396f3dc6196ea7776f21138dfa6d151fec807ab4fa79d32b4e2566bf1f64v.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/be6m243a6fe1cf17474d862c5dbe0f426a799818117ded6ef9f926fd90631axpf.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bejwe33b61163a3ae9380cf9a8c86424f8af0d506127bc117f11d80ba4ef1syc6.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bfo70d3b1de3a0d31c00e0de61de8eabcd163be8b8bb16e3bd33dcc861d9b20nb.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bhqcb3c20100158c1b161056d452779e7350e361e263f8e64b1661151888dl0sb.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bikf6a6f32d265401ea2333313b371276568782b34a8c5ad1f95be841636baxa7.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bkgj33a59b95a5dea4e9d08d4555035d2ad983d4569fe656655ddfa833313alwj.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bosx60112647800231878a646708ba8041ee8f1206f54f5b21918e6e14f411ojs.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bqww9639c67131f241aca389400783d12de3151ee0112b4344107651046ccunne.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bsb65998aab6851029ba6bea01f90b9b10835d9b7f8cfd07e78cfa494b2836fad.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bvsu7d9b66d87598556eedbab78ecbf6cd5e6929d57d286695e60c80992275dyi.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bwzf08197c7cd8a3f8e9cffae7ecaf72deec1e34a289130cfffe71f1a8ee43x1p.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bxu6837adc1769413a0494cefd7b424ad6eb34abd45d0d42270ac0a41a0a4mqwm.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/bzmxb24237e5234c50ec87cb4ae20595b0eed32dc6ea709e0c4220fb53ff4bhn6.jpg: corrupt JPEG restored and saved
# train: /workspace/datasets/dataset2yolo/photo/train/angry/c0565b8c0b6e111306595b29ea475033ff16a1095b3f2b5535063c50b375bd9de.jpg: corrupt JPEG restored and saved
# ...
# val: /workspace/datasets/dataset2yolo/photo/val/sad/k5lgd5ec835ebfb5bfffe15f9a8ea3f31deb05857fdec702bfd314d6e725c9ee2.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/kcs75ecfad525336aa7457758d9e003c70750f1d8c6a642e2f1f33322cc1ar4a0.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/kdwt2a6cff13bab1549cb8a6b3b0a1a1c8838733e8aa35b5ba3b7535ec160rgse.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/kxkc1bfd5c172d8dddc317b149fbbd394dcdebdc7151919f1dbdaf7aa9bf22m1o.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/kyq2942c125aaa61cb745657852a6475bc76b10b46673b171e61c342cea562asx.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/l1ylff815e3f9ab40a56b93bca0db3cdab2cf7b08d9db181ed6cdaece39d5rpqm.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/l7308e7c010190c31ee9c51603905fef6405d907de81091c5b6d51cf15396si3q.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/leel74df0ec4466e9181fde630f0041124454611f02eff56050d8644741f4ugw4.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/lhmof2ea1021b309d0fa45398ab1550a7c94930905eaed6a41a00ac0ba9793dry.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/lidx15c7022044b38720fe79527ef273838bbd8be08b244b3d0c04d06d79einat.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/lxfj1212464fde3fec55e5243645351148a6464a4640409ca41dace5483194f6n.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/m5pc7123a88b11cf131f1ce81a43aaba361ae3dd687313e17a4a2c1bb1141rwbb.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/mhk4a6b5c8aba96a5a7628308c2043666901a40c3ac7cc8116d96743fc9630am0.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/mo6vc55a464963c94244d54e41eed2a3ccea117cd6e8153ecf5e94c3b6df5r6ob.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/moxwf2b0ef5f8e4772e097c99bf622b827b22f2e794ccff29d5f010ef9585cvqc.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/na6bc95701303c5393d204374a8213df333c86de7d9ebf931334f3ca3a3ff7scg.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/nilg624a17465e39c7758ac42427a23643c38c00d4a729935613c2725a98c77r9.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/nvaa2af3e049d151342a9b01282fa0f5934aca02bd5506951578789810d98079j.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/ouuz558559db6bd198de90fc6b9102779902222c11f015099dcd9b6fa090dv9uf.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/ow0862307724171bce51e77a4344c53fdc64e56f710d9906558a1ac3f56334r7f.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/p0bvdc668a7e367b4443b567ee8d3fe3cc9b3c93a7ec9d49225693587eab4ljzc.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/p65a6f13250efef60521595f5a5b4315be9254214624a395c45a42555d3b4pke2.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/ph6zd793c763e90fc375e05304b5bfc21011d5b303b00deb41a3cd5453637gu5b.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/phi8dbfa6280e0a67663637746f236ca595270503ea39eee066654186386ex249.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/ps1u2a8e123bf668313700b7018c9a0b89383b9a1d697256270b519a6b1cb3zaz.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/pue1a26ed245cc192fcc6616c8b5278f189fccce7b125c28f8be8c46269ad6ho3.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/py2k051989f663d2203eed758004073c24b0c810595a0deb7f64d96fa178d5b6d.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/q23q9bf6dd6f6bf4d6b39bbc3f6ccbf24800b923dcc35963503fa03d6a0ablxb9.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/qha269680504df7c8d266e5cb472e26b90fe72e06d52325d96559b5610f62neal.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/qq9vef20ea156b7eead00b8b6fcfcc9621adefad6ef10536675933a6e9ef6ni16.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/qvyx0f85ae92c9c3200fa469edc101dccaed9600780f6494f6d2aeea2dd583a38.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/r07ed409980d004f90580ae066587c5cb4b3b122585c2e028b95511ce5ccdpp4i.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/rfd847522aaccfc00c1affae60d446fb4e721c7fe0a5a13df1a706bad6e47v1kj.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/rr42b59296256d25a7fa194556522b2dcdbd2b256501cc72c59a196231345xhub.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/rv43c18ab4deb6f47ffed1ebefd81dbf2e3ca7d2a7eb20d2d99153557ebefmkzc.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/s0rl2d1ebe02babf9aa499b3f2a1c0f4c1a7e7ac1b901b54e142f2a323123fdxn.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/sm612198a884e3e9fc523206c7330e719234b388f9848226b1a339c2c32b07v5v.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/spxic8f302faa391aeeada3b71a55a4049a0704d99b30e47009cb9aef7ceey7wh.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/t21i4bb0507bfb442604fa4a6a88536028034e4e8c75677c547554717e6c8abc6.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/t4v2622835ef5f775372375650b368e722376e53be3b4757b5236fa063547eqzg.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/taux68422d90e8e90929a0eed5c4e78f8092a79815982f3227d933968674140u0.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/tfto9da6deadad5983eae029a2854ddd355b9ab8cdd0593c4a5fd2adbde639hyf.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/tpm12aa99033a15b3bee011e51770129211a2622171b02b2e0806bbe112695f22.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/ub3wcd6e1ddef519cee1a3c4ffcec24e9447434911bbb2e7a892bb0eff0cfafll.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/uesnda8bd183c3543ba21a13594fb52981d85b0b08153870b95f15c2b8c913glw.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/uiqe4b0da931ea9fd65a415ef201a4693c90ff440a69fc44d1a3ab2431fban52e.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/ut5pc330e3e535bacfc4dc11d79eab9bed6ddbadb4fb144feba9bb447eb82f0sq.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/uwo9d609c66678db9a0a8b5db261098c264b461eeadf1d9dfd66c511ea5b4wlh6.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/uxg4c6de1ed190328509e22b512cd7d92fd9082fdf3e35797d197dd5ce2e3srfz.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/vaf19e5b5115104cf15d50122270474f5f86a48fe13b400e441212572df940p5d.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/vccb232f76d5750711f2f0de3347f7fdb8cb284627f7788930492bf0830f4ntwn.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/vsibdd90aec3cd848778c2317a977547d5cdc8d09872d8f3775ebdb758988ardx.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/vvpjde1337037b5ff195e4483fbb6d7f3972ab9157d6d273bda7258ecf7d5gcb2.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/vxy524d1dd6bfc2ed96b6010ed0dcdc6c25c627d1c4934d91347b12dc42eefkrt.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/w76oaf04a317a7bb33a3eca33b41a3b02cceac116ddb11ae15e7ea157db76v9gt.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/w997091fff3e29c282f22a9468f9f9df812af9ff4020158f8f2014d95d9fc2bnd.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/wbic9503bb67c933b9b79f0bd381fab100b920eaa1b370beb08bbb7fb893artjm.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/weyh4ed204a56ac41ed161cfd60892ed19aad46c94c166216e65fe992421c6hvb.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/wiex32d1d1acbf2912dadf9b9018d27f1232e2918691922a81b198bf0492a6ouj.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/wjxsc6f19e57946c4dd0d025627752809e6924452e60c231abb5374d2135eu4z0.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/wqxe5c9a65044c48c64146f934fefbf75d18947d95544b7c4ca1aced96ca1m8tf.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/wtf1cb33466393043a9a05a4458b955a0f7bbd00b53c9ad62253925b6a3737vly.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/xbl035b9cc7b5fe4ee8423f43f58f005ccc3c873dd05789729bb58cb77f77cw5u.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/xkv9e820952c4ab667b55b414c4c3ac951af8c51c5bce82a504eac774529552j1.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/xxy0ab160b048b494e4b1464bd6a6c2ea271822941d4d06ee3da24d520e2c7dep.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/y6cs303f1682b884f87756482278775e03ea6abdd7b15c6e5020d3e6ec7ceayh6.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/y88v003bed1c0abea9d099dbbb5061c0b62e2f504905e492159bf130eaed0rw9i.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/yoqce47d521d4b17463cb0b586642a0ac4ff55e0393c5e4c00ac0ec7646bd9f6m.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/yps8ff717d9fc15e95c1ff119757e2f6cd14fc71f00ed7cf5e0511f9ef69fzsd3.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/yv7v99a9c46ee15de024dd191c406cbedd4f1d69ca919566040001a607d1dwx3b.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/z08jae54f753154b08e8ceac0888f21981cea58bf633f6f77351f03adac7bjuss.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/zd1gba0cc40e56b355ef582f62f55136ad342685c1570d85e1d7c02fd54c8zwxh.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/zhzyab2587f27b6d0ba340f474f234c736b3a1087243739ba87c94c7a7bdf1253.jpg: corrupt JPEG restored and saved
# val: /workspace/datasets/dataset2yolo/photo/val/sad/zzy20c2a35f933560fbe515050315bbf65ec99bb46b65fe0b9ca13ce5c5bcb3ej.jpg: corrupt JPEG restored and saved
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.0005), 51 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to runs/classify/train21
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/10      3.01G     0.9996         28        224: 100%|██████████| 180/180 [01:22<00:00,  2.17it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  2.97it/s]
#                    all      0.772          1
#       Epoch    GPU_mem       loss  Instances       Size
#        2/10      3.46G     0.6383         28        224: 100%|██████████| 180/180 [01:16<00:00,  2.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  2.95it/s]
#                    all      0.753          1
#       Epoch    GPU_mem       loss  Instances       Size
#        3/10      3.46G     0.6031         28        224: 100%|██████████| 180/180 [01:12<00:00,  2.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  3.04it/s]
#                    all      0.733          1
#       Epoch    GPU_mem       loss  Instances       Size
#        4/10      3.46G     0.5651         28        224: 100%|██████████| 180/180 [01:14<00:00,  2.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  3.12it/s]
#                    all      0.827          1
#       Epoch    GPU_mem       loss  Instances       Size
#        5/10      3.46G     0.4963         28        224: 100%|██████████| 180/180 [01:14<00:00,  2.41it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:08<00:00,  2.85it/s]
#                    all      0.851          1
#       Epoch    GPU_mem       loss  Instances       Size
#        6/10      3.46G     0.4413         28        224: 100%|██████████| 180/180 [01:14<00:00,  2.41it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:08<00:00,  2.65it/s]
#                    all      0.863          1
#       Epoch    GPU_mem       loss  Instances       Size
#        7/10      3.46G     0.3782         28        224: 100%|██████████| 180/180 [01:15<00:00,  2.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  3.17it/s]
#                    all      0.858          1
#       Epoch    GPU_mem       loss  Instances       Size
#        8/10      3.46G     0.3371         28        224: 100%|██████████| 180/180 [01:19<00:00,  2.28it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  2.94it/s]
#                    all      0.874          1
#       Epoch    GPU_mem       loss  Instances       Size
#        9/10      3.46G     0.2887         28        224: 100%|██████████| 180/180 [01:15<00:00,  2.37it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:07<00:00,  3.07it/s]
#                    all      0.879          1
#       Epoch    GPU_mem       loss  Instances       Size
#       10/10      3.46G      0.255         28        224: 100%|██████████| 180/180 [01:15<00:00,  2.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:08<00:00,  2.87it/s]
#                    all      0.892          1
# 10 epochs completed in 0.243 hours.
# Optimizer stripped from runs/classify/train21/weights/last.pt, 112.5MB
# Optimizer stripped from runs/classify/train21/weights/best.pt, 112.5MB
#
# Validating runs/classify/train21/weights/best.pt...
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.7.1+cu118 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20147MiB)
# YOLOv8x-cls summary (fused): 54 layers, 56,128,324 parameters, 0 gradients, 153.8 GFLOPs
# train: /workspace/datasets/dataset2yolo/photo/train... found 5756 images in 4 classes ✅
# val: /workspace/datasets/dataset2yolo/photo/val... found 1440 images in 4 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 23/23 [00:16<00:00,  1.41it/s]
#                    all      0.892          1
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train21
# 📁 사진 기반 사전학습 모델 저장 완료: /workspace/models/photo_pretrained_yolov8x.pt

# %%
# 2️⃣ Step 2 - 그림 데이터로 파인튜닝 (사진 모델 이어서)
print("\n🟣 Step 2: 그림 데이터로 파인튜닝")

# 이전 학습된 모델 불러오기
model2 = YOLO(PRETRAINED_MODEL_PATH)

results2 = model2.train(
    data=DRAWING_DATA_PATH,
    epochs=EPOCHS_DRAWING,
    imgsz=IMG_SIZE,
    batch=BATCH_SIZE,
    patience=PATIENCE,
    device=DEVICE,
    # 데이터 증강 설정
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=10,
    translate=0.1,
    scale=0.5,
    shear=0.0,
    perspective=0.0,
    flipud=0.0,
    fliplr=0.5,
    mosaic=0.0,  # 분류 태스크에서는 mosaic 비활성화
    mixup=0.1,
    copy_paste=0.0
)

# 파인튜닝 모델 저장
model2.save(FINAL_MODEL_PATH)
print(f"📁 파인튜닝된 모델 저장 완료: {FINAL_MODEL_PATH}")
# Out:
# 🟣 Step 2: 그림 데이터로 파인튜닝
# New https://pypi.org/project/ultralytics/8.3.159 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.7.1+cu118 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20147MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/workspace/datasets/dataset2yolo/drawing, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=/workspace/models/photo_pretrained_yolov8x.pt, momentum=0.937, mosaic=0.0, multi_scale=False, name=train22, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=7, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/classify/train22, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /workspace/datasets/dataset2yolo/drawing/train... found 1539 images in 4 classes ✅
# val: /workspace/datasets/dataset2yolo/drawing/val... found 472 images in 4 classes ✅
# test: None...
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  3  27865600  ultralytics.nn.modules.block.C2f             [1280, 1280, 3, True]
#   9                  -1  1   1646084  ultralytics.nn.modules.head.Classify         [1280, 4]
# YOLOv8x-cls summary: 104 layers, 56,146,964 parameters, 56,146,964 gradients, 154.3 GFLOPs
# Transferred 302/302 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.3±0.1 ms, read: 8.8±3.6 MB/s, size: 32.6 KB)
# train: Scanning /workspace/datasets/dataset2yolo/drawing/train... 1539 images, 0 corrupt: 100%|██████████| 1539/1539 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 0.3±0.0 ms, read: 10.4±3.8 MB/s, size: 30.6 KB)
# val: Scanning /workspace/datasets/dataset2yolo/drawing/val... 472 images, 0 corrupt: 100%|██████████| 472/472 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 50 weight(decay=0.0), 51 weight(decay=0.0005), 51 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to runs/classify/train22
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/200      4.03G       1.79          3        224: 100%|██████████| 49/49 [00:06<00:00,  7.96it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.20it/s]
#                    all      0.614          1
#       Epoch    GPU_mem       loss  Instances       Size
#       2/200      4.46G      1.005          3        224: 100%|██████████| 49/49 [00:04<00:00, 10.93it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.26it/s]
#                    all      0.693          1
#       Epoch    GPU_mem       loss  Instances       Size
#       3/200      4.46G     0.8667          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.72it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.05it/s]
#                    all      0.744          1
#       Epoch    GPU_mem       loss  Instances       Size
#       4/200      4.46G     0.8204          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.23it/s]
#                    all      0.667          1
#       Epoch    GPU_mem       loss  Instances       Size
#       5/200      4.46G     0.7931          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.60it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.15it/s]
#                    all       0.75          1
#       Epoch    GPU_mem       loss  Instances       Size
#       6/200      4.49G      0.715          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.18it/s]
#                    all      0.792          1
#       Epoch    GPU_mem       loss  Instances       Size
#       7/200       4.5G     0.6592          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.69it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.23it/s]
#                    all      0.788          1
#       Epoch    GPU_mem       loss  Instances       Size
#       8/200      4.89G     0.6103          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.23it/s]
#                    all      0.807          1
#       Epoch    GPU_mem       loss  Instances       Size
#       9/200      5.12G     0.5409          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.72it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.22it/s]
#                    all      0.826          1
#       Epoch    GPU_mem       loss  Instances       Size
#      10/200       5.5G     0.5624          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.02it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.16it/s]
#                    all      0.831          1
#       Epoch    GPU_mem       loss  Instances       Size
#      11/200       5.5G     0.5377          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.87it/s]
#                    all      0.811          1
#       Epoch    GPU_mem       loss  Instances       Size
#      12/200       5.5G     0.5863          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.09it/s]
#                    all      0.803          1
#       Epoch    GPU_mem       loss  Instances       Size
#      13/200       5.5G     0.5173          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.66it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.02it/s]
#                    all      0.822          1
#       Epoch    GPU_mem       loss  Instances       Size
#      14/200       5.5G      0.407          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.96it/s]
#                    all      0.852          1
#       Epoch    GPU_mem       loss  Instances       Size
#      15/200       5.5G      0.449          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.97it/s]
#                    all      0.839          1
#       Epoch    GPU_mem       loss  Instances       Size
#      16/200       5.5G     0.4845          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.99it/s]
#                    all       0.82          1
#       Epoch    GPU_mem       loss  Instances       Size
#      17/200       5.5G     0.4497          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.06it/s]
#                    all      0.862          1
#       Epoch    GPU_mem       loss  Instances       Size
#      18/200       5.5G      0.437          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.82it/s]
#                    all      0.837          1
#       Epoch    GPU_mem       loss  Instances       Size
#      19/200       5.5G     0.3687          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.11it/s]
#                    all      0.839          1
#       Epoch    GPU_mem       loss  Instances       Size
#      20/200       5.5G     0.3984          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.43it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.03it/s]
#                    all      0.847          1
#       Epoch    GPU_mem       loss  Instances       Size
#      21/200       5.5G     0.4349          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.66it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.18it/s]
#                    all      0.839          1
#       Epoch    GPU_mem       loss  Instances       Size
#      22/200       5.5G     0.3821          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 22.05it/s]
#                    all      0.862          1
#       Epoch    GPU_mem       loss  Instances       Size
#      23/200      5.52G     0.3376          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.65it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.88it/s]
#                    all      0.828          1
#       Epoch    GPU_mem       loss  Instances       Size
#      24/200      5.86G     0.3147          3        224: 100%|██████████| 49/49 [00:04<00:00, 11.44it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 21.87it/s]
#                    all      0.858          1
# EarlyStopping: Training stopped early as no improvement observed in last 7 epochs. Best results observed at epoch 17, best model saved as best.pt.
# To update EarlyStopping(patience=7) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 24 epochs completed in 0.053 hours.
# Optimizer stripped from runs/classify/train22/weights/last.pt, 112.5MB
# Optimizer stripped from runs/classify/train22/weights/best.pt, 112.5MB
#
# Validating runs/classify/train22/weights/best.pt...
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.7.1+cu118 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 20147MiB)
# YOLOv8x-cls summary (fused): 54 layers, 56,128,324 parameters, 0 gradients, 153.8 GFLOPs
# train: /workspace/datasets/dataset2yolo/drawing/train... found 1539 images in 4 classes ✅
# val: /workspace/datasets/dataset2yolo/drawing/val... found 472 images in 4 classes ✅
# test: None...
#                classes   top1_acc   top5_acc: 100%|██████████| 8/8 [00:00<00:00, 23.14it/s]
#                    all      0.862          1
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train22
# 📁 파인튜닝된 모델 저장 완료: /workspace/models/drawing_finetuned_yolov8x.pt

# %%
# 파인튜닝된 모델 로드
print("🔵 파인튜닝된 모델 로드 중...")
model = YOLO(FINAL_MODEL_PATH)
model.fuse()

# 클래스 이름 확인
class_names = model.names
print(f"📋 클래스 수: {len(class_names)}")
print(f"📋 클래스 이름: {list(class_names.values())}")

# 예측할 이미지 폴더 설정
image_dir = os.path.join(DRAWING_DATA_PATH, "val")

# 폴더 존재 여부 확인
if not os.path.exists(image_dir):
    print(f"❌ val 폴더가 존재하지 않습니다: {image_dir}")
    exit()

print(f"📁 이미지 경로: {image_dir}")

# 모든 이미지 경로 수집
all_images = []
class_counts = {}

try:
    for cls in os.listdir(image_dir):
        cls_path = os.path.join(image_dir, cls)
        if os.path.isdir(cls_path):
            img_files = [f for f in os.listdir(cls_path) 
                        if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff'))]
            
            class_counts[cls] = len(img_files)
            print(f"🔍 클래스 '{cls}': {len(img_files)}장 수집")
            
            for img_name in img_files:
                img_path = os.path.join(cls_path, img_name)
                all_images.append((img_path, cls))
    
    total_images = len(all_images)
    print(f"✅ 총 {total_images}장의 이미지 수집 완료")
    
except Exception as e:
    print(f"❌ 이미지 수집 중 오류: {e}")
    exit()

# 이미지가 있는지 확인
if len(all_images) == 0:
    print("❌ 예측할 이미지가 없습니다!")
    exit()

print(f"🎯 전체 {total_images}장 이미지로 성능 평가 진행")

# 클래스별 예측 결과 저장
from collections import defaultdict
class_results = defaultdict(lambda: {'correct': 0, 'total': 0, 'predictions': []})

correct_predictions = 0
total_predictions = 0

# 모든 이미지에 대해 예측 수행
for idx, (img_path, true_label) in enumerate(all_images):
    try:
        # 모델 예측
        result = model.predict(source=img_path, imgsz=IMG_SIZE, conf=0.0, verbose=False)[0]
        
        # 예측 결과 추출
        if hasattr(result, 'probs') and result.probs is not None:
            pred_idx = int(result.probs.top1)
            pred_label = class_names[pred_idx]
            confidence = float(result.probs.top1conf)
        else:
            pred_label = "Unknown"
            confidence = 0.0
        
        # 결과 저장
        class_results[true_label]['total'] += 1
        class_results[true_label]['predictions'].append({
            'predicted': pred_label,
            'confidence': confidence,
            'correct': pred_label == true_label
        })
        
        if pred_label == true_label:
            class_results[true_label]['correct'] += 1
            correct_predictions += 1
        
        total_predictions += 1
        
    except Exception as e:
        print(f"❌ 이미지 {idx+1} 처리 중 오류: {e}")
        continue

print(f"✅ 전체 예측 완료!")

# 전체 정확도 출력
overall_accuracy = correct_predictions / total_predictions * 100 if total_predictions > 0 else 0
print(f"\n🎯 전체 성능 요약")
print(f"📊 전체 정확도: {correct_predictions}/{total_predictions} = {overall_accuracy:.2f}%")

# 클래스별 성능 상세 출력
print(f"\n📈 클래스별 상세 성능:")
print("=" * 60)

for cls in sorted(class_results.keys()):
    results = class_results[cls]
    if results['total'] > 0:
        cls_accuracy = results['correct'] / results['total'] * 100
        
        print(f"🏷️  클래스: {cls}")
        print(f"   📸 총 이미지 수: {results['total']}장")
        print(f"   ✅ 정답 예측: {results['correct']}장")
        print(f"   ❌ 오답 예측: {results['total'] - results['correct']}장")
        print(f"   📊 정확도: {cls_accuracy:.2f}%")
        
        # 평균 신뢰도 계산
        confidences = [p['confidence'] for p in results['predictions']]
        avg_confidence = sum(confidences) / len(confidences) if confidences else 0
        print(f"   🎯 평균 신뢰도: {avg_confidence:.3f}")
        print("-" * 40)

# 혼동 행렬 형태로 오분류 분석
print(f"\n🔍 오분류 분석:")
print("=" * 60)

confusion_data = defaultdict(lambda: defaultdict(int))

for true_cls, results in class_results.items():
    for pred_info in results['predictions']:
        pred_cls = pred_info['predicted']
        confusion_data[true_cls][pred_cls] += 1

# 헤더 출력
classes = sorted(class_results.keys())
header = "실제\\예측"
print(f"{header:<10}", end="")
for cls in classes:
    print(f"{cls:<10}", end="")
print()

# 각 행 출력
for true_cls in classes:
    print(f"{true_cls:<10}", end="")
    for pred_cls in classes:
        count = confusion_data[true_cls][pred_cls]
        print(f"{count:<10}", end="")
    print()

print("\n✅ 성능 평가 완료!")
# Out:
# 🔵 파인튜닝된 모델 로드 중...
# YOLOv8x-cls summary (fused): 54 layers, 56,128,324 parameters, 0 gradients, 153.8 GFLOPs
# 📋 클래스 수: 4
# 📋 클래스 이름: ['angry', 'fear', 'happy', 'sad']
# 📁 이미지 경로: /workspace/datasets/dataset2yolo/drawing/val
# 🔍 클래스 'fear': 91장 수집
# 🔍 클래스 'angry': 100장 수집
# 🔍 클래스 'happy': 182장 수집
# 🔍 클래스 'sad': 96장 수집
# ✅ 총 469장의 이미지 수집 완료
# 🎯 전체 469장 이미지로 성능 평가 진행
# ✅ 전체 예측 완료!
#
# 🎯 전체 성능 요약
# 📊 전체 정확도: 404/469 = 86.14%
#
# 📈 클래스별 상세 성능:
# ============================================================
# 🏷️  클래스: angry
#    📸 총 이미지 수: 100장
#    ✅ 정답 예측: 83장
#    ❌ 오답 예측: 17장
#    📊 정확도: 83.00%
#    🎯 평균 신뢰도: 0.905
# ----------------------------------------
# 🏷️  클래스: fear
#    📸 총 이미지 수: 91장
#    ✅ 정답 예측: 68장
#    ❌ 오답 예측: 23장
#    📊 정확도: 74.73%
#    🎯 평균 신뢰도: 0.899
# ----------------------------------------
# 🏷️  클래스: happy
#    📸 총 이미지 수: 182장
#    ✅ 정답 예측: 176장
#    ❌ 오답 예측: 6장
#    📊 정확도: 96.70%
#    🎯 평균 신뢰도: 0.936
# ----------------------------------------
# 🏷️  클래스: sad
#    📸 총 이미지 수: 96장
#    ✅ 정답 예측: 77장
#    ❌ 오답 예측: 19장
#    📊 정확도: 80.21%
#    🎯 평균 신뢰도: 0.895
# ----------------------------------------
#
# 🔍 오분류 분석:
# ============================================================
# 실제\예측     angry     fear      happy     sad
# angry     83        8         5         4
# fear      7         68        5         11
# happy     4         0         176       2
# sad       2         7         10        77
#
# ✅ 성능 평가 완료!

# %%
# 필요한 라이브러리 import
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import pandas as pd

# 한글 폰트 설정 (matplotlib에서 한글 표시를 위해)
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['axes.unicode_minus'] = False

print("\n" + "="*80)
print("🔥 상세 성능 지표 분석 시작")
print("="*80)

# 예측 결과를 리스트로 변환
y_true = []
y_pred = []
y_pred_proba = []

for true_cls, results in class_results.items():
    for pred_info in results['predictions']:
        y_true.append(true_cls)
        y_pred.append(pred_info['predicted'])
        y_pred_proba.append(pred_info['confidence'])

# 클래스 리스트 생성
classes = sorted(list(set(y_true + y_pred)))
print(f"📋 분석할 클래스: {classes}")

# 1. 기본 성능 지표 계산
print(f"\n📊 기본 성능 지표")
print("-" * 50)

# 전체 정확도
accuracy = accuracy_score(y_true, y_pred)
print(f"🎯 정확도 (Accuracy): {accuracy:.4f} ({accuracy*100:.2f}%)")

# 매크로 평균 지표
macro_precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
macro_recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
macro_f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)

print(f"🔍 매크로 평균 Precision: {macro_precision:.4f}")
print(f"🔍 매크로 평균 Recall: {macro_recall:.4f}")
print(f"🔍 매크로 평균 F1-Score: {macro_f1:.4f}")

# 가중 평균 지표
weighted_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
weighted_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
weighted_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print(f"⚖️  가중 평균 Precision: {weighted_precision:.4f}")
print(f"⚖️  가중 평균 Recall: {weighted_recall:.4f}")
print(f"⚖️  가중 평균 F1-Score: {weighted_f1:.4f}")

# 2. 클래스별 상세 성능 지표
print(f"\n📈 클래스별 상세 성능 지표")
print("-" * 50)

# sklearn의 classification_report 사용
report = classification_report(y_true, y_pred, output_dict=True, zero_division=0)
report_df = pd.DataFrame(report).transpose()

print(f"{'클래스':<15} {'Precision':<10} {'Recall':<10} {'F1-Score':<10} {'Support':<10}")
print("-" * 65)

for class_name in classes:
    if class_name in report:
        precision = report[class_name]['precision']
        recall = report[class_name]['recall']
        f1 = report[class_name]['f1-score']
        support = report[class_name]['support']
        
        print(f"{class_name:<15} {precision:<10.3f} {recall:<10.3f} {f1:<10.3f} {support:<10.0f}")

# 3. 혼동 행렬 생성 및 시각화
print(f"\n🔍 혼동 행렬 (Confusion Matrix)")
print("-" * 50)

cm = confusion_matrix(y_true, y_pred, labels=classes)

# 혼동 행렬 시각화
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=classes, yticklabels=classes)
plt.title('혼동 행렬 (Confusion Matrix)', fontsize=16, pad=20)
plt.xlabel('예측 클래스', fontsize=12)
plt.ylabel('실제 클래스', fontsize=12)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# 4. 클래스별 성능 시각화
print(f"\n📊 클래스별 성능 시각화")
print("-" * 50)

# 클래스별 지표를 데이터프레임으로 정리
class_metrics = []
for class_name in classes:
    if class_name in report:
        class_metrics.append({
            'Class': class_name,
            'Precision': report[class_name]['precision'],
            'Recall': report[class_name]['recall'],
            'F1-Score': report[class_name]['f1-score'],
            'Support': report[class_name]['support']
        })

metrics_df = pd.DataFrame(class_metrics)

# 바 차트로 시각화
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Precision
axes[0, 0].bar(metrics_df['Class'], metrics_df['Precision'], color='skyblue')
axes[0, 0].set_title('클래스별 Precision', fontsize=14)
axes[0, 0].set_ylabel('Precision')
axes[0, 0].tick_params(axis='x', rotation=45)

# Recall
axes[0, 1].bar(metrics_df['Class'], metrics_df['Recall'], color='lightgreen')
axes[0, 1].set_title('클래스별 Recall', fontsize=14)
axes[0, 1].set_ylabel('Recall')
axes[0, 1].tick_params(axis='x', rotation=45)

# F1-Score
axes[1, 0].bar(metrics_df['Class'], metrics_df['F1-Score'], color='salmon')
axes[1, 0].set_title('클래스별 F1-Score', fontsize=14)
axes[1, 0].set_ylabel('F1-Score')
axes[1, 0].tick_params(axis='x', rotation=45)

# Support (샘플 수)
axes[1, 1].bar(metrics_df['Class'], metrics_df['Support'], color='gold')
axes[1, 1].set_title('클래스별 샘플 수', fontsize=14)
axes[1, 1].set_ylabel('Sample Count')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# 5. 신뢰도 분석
print(f"\n🎯 신뢰도 분석")
print("-" * 50)

# 신뢰도 통계
confidence_stats = {
    'mean': np.mean(y_pred_proba),
    'std': np.std(y_pred_proba),
    'min': np.min(y_pred_proba),
    'max': np.max(y_pred_proba),
    'median': np.median(y_pred_proba)
}

print(f"📊 신뢰도 통계:")
print(f"   평균: {confidence_stats['mean']:.3f}")
print(f"   표준편차: {confidence_stats['std']:.3f}")
print(f"   최솟값: {confidence_stats['min']:.3f}")
print(f"   최댓값: {confidence_stats['max']:.3f}")
print(f"   중앙값: {confidence_stats['median']:.3f}")

# 신뢰도 히스토그램
plt.figure(figsize=(10, 6))
plt.hist(y_pred_proba, bins=30, alpha=0.7, color='steelblue', edgecolor='black')
plt.title('예측 신뢰도 분포', fontsize=14)
plt.xlabel('신뢰도 (Confidence)')
plt.ylabel('빈도 (Frequency)')
plt.axvline(confidence_stats['mean'], color='red', linestyle='--', 
           label=f'평균: {confidence_stats["mean"]:.3f}')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 6. 성능 요약 리포트
print(f"\n📋 최종 성능 요약 리포트")
print("=" * 80)

summary_data = {
    '지표': ['정확도', '매크로 평균 Precision', '매크로 평균 Recall', '매크로 평균 F1-Score',
            '가중 평균 Precision', '가중 평균 Recall', '가중 평균 F1-Score'],
    '값': [f"{accuracy:.4f}", f"{macro_precision:.4f}", f"{macro_recall:.4f}", 
          f"{macro_f1:.4f}", f"{weighted_precision:.4f}", f"{weighted_recall:.4f}", 
          f"{weighted_f1:.4f}"],
    '백분율': [f"{accuracy*100:.2f}%", f"{macro_precision*100:.2f}%", 
              f"{macro_recall*100:.2f}%", f"{macro_f1*100:.2f}%",
              f"{weighted_precision*100:.2f}%", f"{weighted_recall*100:.2f}%", 
              f"{weighted_f1*100:.2f}%"]
}

summary_df = pd.DataFrame(summary_data)
print(summary_df.to_string(index=False))

# 7. 오분류 상위 사례 분석
print(f"\n❌ 오분류 사례 분석")
print("-" * 50)

# 오분류된 사례들을 수집
misclassified = []
for i, (true_label, pred_label, confidence) in enumerate(zip(y_true, y_pred, y_pred_proba)):
    if true_label != pred_label:
        misclassified.append({
            'true_label': true_label,
            'pred_label': pred_label,
            'confidence': confidence,
            'index': i
        })

print(f"🔍 총 오분류 사례: {len(misclassified)}개")

if misclassified:
    # 신뢰도가 높은 오분류 사례 (모델이 확신했지만 틀린 경우)
    high_conf_errors = sorted(misclassified, key=lambda x: x['confidence'], reverse=True)[:5]
    
    print(f"\n🚨 고신뢰도 오분류 사례 (상위 5개):")
    for i, error in enumerate(high_conf_errors, 1):
        print(f"   {i}. 실제: {error['true_label']} → 예측: {error['pred_label']} "
              f"(신뢰도: {error['confidence']:.3f})")
    
    # 가장 많이 혼동되는 클래스 쌍 찾기
    confusion_pairs = {}
    for error in misclassified:
        pair = (error['true_label'], error['pred_label'])
        confusion_pairs[pair] = confusion_pairs.get(pair, 0) + 1
    
    top_confusions = sorted(confusion_pairs.items(), key=lambda x: x[1], reverse=True)[:5]
    
    print(f"\n🔄 주요 혼동 클래스 쌍 (상위 5개):")
    for i, ((true_cls, pred_cls), count) in enumerate(top_confusions, 1):
        print(f"   {i}. {true_cls} → {pred_cls}: {count}회")

print(f"\n✅ 상세 성능 분석 완료!")
print("=" * 80)
# Out:
# ================================================================================
# 🔥 상세 성능 지표 분석 시작
# ================================================================================
# 📋 분석할 클래스: ['angry', 'fear', 'happy', 'sad']
#
# 📊 기본 성능 지표
# --------------------------------------------------
# 🎯 정확도 (Accuracy): 0.8614 (86.14%)
# 🔍 매크로 평균 Precision: 0.8502
# 🔍 매크로 평균 Recall: 0.8366
# 🔍 매크로 평균 F1-Score: 0.8426
# ⚖️  가중 평균 Precision: 0.8594
# ⚖️  가중 평균 Recall: 0.8614
# ⚖️  가중 평균 F1-Score: 0.8595
#
# 📈 클래스별 상세 성능 지표
# --------------------------------------------------
# 클래스             Precision  Recall     F1-Score   Support
# -----------------------------------------------------------------
# angry           0.865      0.830      0.847      100
# fear            0.819      0.747      0.782      91
# happy           0.898      0.967      0.931      182
# sad             0.819      0.802      0.811      96
#
# 🔍 혼동 행렬 (Confusion Matrix)
# --------------------------------------------------
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 53364 (\N{HANGUL SYLLABLE KEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 54844 (\N{HANGUL SYLLABLE HON}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:93: UserWarning: Glyph 47148 (\N{HANGUL SYLLABLE RYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 53364 (\N{HANGUL SYLLABLE KEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54844 (\N{HANGUL SYLLABLE HON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47148 (\N{HANGUL SYLLABLE RYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 53364 (\N{HANGUL SYLLABLE KEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# 📊 클래스별 성능 시각화
# --------------------------------------------------
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_108298/4166252132.py:141: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49368 (\N{HANGUL SYLLABLE SAEM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 🎯 신뢰도 분석
# --------------------------------------------------
# 📊 신뢰도 통계:
#    평균: 0.914
#    표준편차: 0.139
#    최솟값: 0.371
#    최댓값: 1.000
#    중앙값: 0.988
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48712 (\N{HANGUL SYLLABLE BIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47280 (\N{HANGUL SYLLABLE ROE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /workspace/.conda/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📋 최종 성능 요약 리포트
# ================================================================================
#               지표      값    백분율
#              정확도 0.8614 86.14%
# 매크로 평균 Precision 0.8502 85.02%
#    매크로 평균 Recall 0.8366 83.66%
#  매크로 평균 F1-Score 0.8426 84.26%
#  가중 평균 Precision 0.8594 85.94%
#     가중 평균 Recall 0.8614 86.14%
#   가중 평균 F1-Score 0.8595 85.95%
#
# ❌ 오분류 사례 분석
# --------------------------------------------------
# 🔍 총 오분류 사례: 65개
#
# 🚨 고신뢰도 오분류 사례 (상위 5개):
#    1. 실제: fear → 예측: sad (신뢰도: 1.000)
#    2. 실제: angry → 예측: sad (신뢰도: 1.000)
#    3. 실제: fear → 예측: angry (신뢰도: 1.000)
#    4. 실제: angry → 예측: sad (신뢰도: 0.999)
#    5. 실제: fear → 예측: sad (신뢰도: 0.998)
#
# 🔄 주요 혼동 클래스 쌍 (상위 5개):
#    1. fear → sad: 11회
#    2. sad → happy: 10회
#    3. angry → fear: 8회
#    4. fear → angry: 7회
#    5. sad → fear: 7회
#
# ✅ 상세 성능 분석 완료!
# ================================================================================
